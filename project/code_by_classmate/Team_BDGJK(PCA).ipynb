# %% [markdown]
# # 1. Load data

# %% [markdown]
# **The author use Colab**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

  #as what we learnt from COM6001 (modify the path to fit with yours)
df = pd.read_excel('Residential-Building-Data-Set.xlsx',   #1: specify your excel
                     sheet_name='Data',                         #2: specify your sheet
                     skiprows=1,                                #3: one row is affecting the creation of dataframe, so it is skipped
                     header=0                                   #4: then, we have a header at the beginning
                     )
df[['START YEAR','START QUARTER','COMPLETION YEAR','COMPLETION QUARTER','V-9','V-10']]
# Out:
#      START YEAR  START QUARTER  COMPLETION YEAR  COMPLETION QUARTER   V-9  \
# 0            81              1               85                   1  2200
# 1            84              1               89                   4  5000
# 2            78              1               81                   4  1200
# 3            72              2               73                   2   165
# 4            87              1               90                   2  5500
# ..          ...            ...              ...                 ...   ...
# 367          83              4               86                   1  1100
# 368          81              2               82                   4   740
# 369          84              4               86                   3   860
# 370          82              3               84                   4  1100
# 371          80              1               81                   3   460
#
#      V-10
# 0     410
# 1    1000
# 2     170
# 3      30
# 4     700
# ..    ...
# 367   150
# 368    80
# 369   220
# 370   110
# 371    50
#
# [372 rows x 6 columns]

# %%
df
# Out:
#      START YEAR  START QUARTER  COMPLETION YEAR  COMPLETION QUARTER  V-1  \
# 0            81              1               85                   1    1
# 1            84              1               89                   4    1
# 2            78              1               81                   4    1
# 3            72              2               73                   2    1
# 4            87              1               90                   2    1
# ..          ...            ...              ...                 ...  ...
# 367          83              4               86                   1   20
# 368          81              2               82                   4   20
# 369          84              4               86                   3   20
# 370          82              3               84                   4   20
# 371          80              1               81                   3   20
#
#         V-2     V-3     V-4  V-5      V-6  ...   V-22.4   V-23.4  V-24.4  \
# 0    3150.0   920.0   598.5  190  1010.84  ...   815.50  1755.00  8002.0
# 1    7600.0  1140.0  3040.0  400   963.81  ...  1316.30  8364.78  8393.0
# 2    4800.0   840.0   480.0  100   689.84  ...   765.80  1755.00  4930.0
# 3     685.0   202.0    13.7   20   459.54  ...   152.25  1442.31  1456.0
# 4    3000.0   800.0  1230.0  410   631.91  ...  2244.10  9231.76  9286.0
# ..      ...     ...     ...  ...      ...  ...      ...      ...     ...
# 367  1350.0   350.0   108.0   80   251.37  ...  1176.50  8343.60  8382.0
# 368   600.0   150.0    36.0   60   299.55  ...   815.50  1755.00  8013.0
# 369  1900.0   430.0   285.0  150   364.41  ...  1584.30  8776.71  8799.0
# 370   510.0   160.0    30.6   60   245.28  ...   909.20  7930.66  8004.0
# 371   890.0   230.0    35.6   40   237.03  ...   764.50  1755.00  8420.0
#
#      V-25.4  V-26.4    V-27.4    V-28.4     V-29.4   V-9  V-10
# 0     60.74   54.26   2978.26  41407.00   601988.1  2200   410
# 1     90.95   89.79  11379.37  44835.00   929027.1  5000  1000
# 2     38.70   32.04   1653.06  37933.00   377828.6  1200   170
# 3      9.73    8.34    686.16   8194.00   122031.7   165    30
# 4    136.60  140.20   9821.00  48260.00  1734973.5  5500   700
# ..      ...     ...       ...       ...        ...   ...   ...
# 367   87.27   85.56  10555.47  33626.25   865878.9  1100   150
# 368   62.78   56.45   3387.72  10646.75   606524.2   740    80
# 369  101.00  101.89  13571.80  34474.50  1067772.0   860   220
# 370   73.57   69.26   4756.68  21855.00   669640.3  1100   110
# 371   54.62   44.79   2206.19  40234.00   629797.2   460    50
#
# [372 rows x 109 columns]

# %% [markdown]
# ## Check Missing Data

# %%
df.isna().sum()
# Out:
# START YEAR            0
# START QUARTER         0
# COMPLETION YEAR       0
# COMPLETION QUARTER    0
# V-1                   0
#                      ..
# V-27.4                0
# V-28.4                0
# V-29.4                0
# V-9                   0
# V-10                  0
# Length: 109, dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# **Findings: No missing data**

# %% [markdown]
# ## Tidy Up the DataFrame

# %% [markdown]
# **Operations are: Fixing year in AD, Renaming Column Header, Moving *Y* in front of *X* for Easy Reading**

# %%
df.columns = df.columns.str.replace('V-9','Actual Sales Price') #give Output 1 a proper name
df.columns = df.columns.str.replace('V-10','Actual Construction Cost') #give Output 2 a proper name
df.columns
# Out:
# Index(['START YEAR', 'START QUARTER', 'COMPLETION YEAR', 'COMPLETION QUARTER',
#        'V-1', 'V-2', 'V-3', 'V-4', 'V-5', 'V-6',
#        ...
#        'V-22.4', 'V-23.4', 'V-24.4', 'V-25.4', 'V-26.4', 'V-27.4', 'V-28.4',
#        'V-29.4', 'Actual Sales Price', 'Actual Construction Cost'],
#       dtype='object', length=109)

# %%
'''fix Persian Calendar to Gregorian Calendar (AD)'''
df['START YEAR'] = df['START YEAR'] + 1921 # make year to be western AD year
df.columns = df.columns.str.replace('START YEAR','START YEAR AD') # and rename column for clarity
df['COMPLETION YEAR'] = df['COMPLETION YEAR'] + 1921
df.columns = df.columns.str.replace('COMPLETION YEAR','COMPLETION YEAR AD')
df
# Out:
#      START YEAR AD  START QUARTER  COMPLETION YEAR AD  COMPLETION QUARTER  \
# 0             2002              1                2006                   1
# 1             2005              1                2010                   4
# 2             1999              1                2002                   4
# 3             1993              2                1994                   2
# 4             2008              1                2011                   2
# ..             ...            ...                 ...                 ...
# 367           2004              4                2007                   1
# 368           2002              2                2003                   4
# 369           2005              4                2007                   3
# 370           2003              3                2005                   4
# 371           2001              1                2002                   3
#
#      V-1     V-2     V-3     V-4  V-5      V-6  ...   V-22.4   V-23.4  V-24.4  \
# 0      1  3150.0   920.0   598.5  190  1010.84  ...   815.50  1755.00  8002.0
# 1      1  7600.0  1140.0  3040.0  400   963.81  ...  1316.30  8364.78  8393.0
# 2      1  4800.0   840.0   480.0  100   689.84  ...   765.80  1755.00  4930.0
# 3      1   685.0   202.0    13.7   20   459.54  ...   152.25  1442.31  1456.0
# 4      1  3000.0   800.0  1230.0  410   631.91  ...  2244.10  9231.76  9286.0
# ..   ...     ...     ...     ...  ...      ...  ...      ...      ...     ...
# 367   20  1350.0   350.0   108.0   80   251.37  ...  1176.50  8343.60  8382.0
# 368   20   600.0   150.0    36.0   60   299.55  ...   815.50  1755.00  8013.0
# 369   20  1900.0   430.0   285.0  150   364.41  ...  1584.30  8776.71  8799.0
# 370   20   510.0   160.0    30.6   60   245.28  ...   909.20  7930.66  8004.0
# 371   20   890.0   230.0    35.6   40   237.03  ...   764.50  1755.00  8420.0
#
#      V-25.4  V-26.4    V-27.4    V-28.4     V-29.4  Actual Sales Price  \
# 0     60.74   54.26   2978.26  41407.00   601988.1                2200
# 1     90.95   89.79  11379.37  44835.00   929027.1                5000
# 2     38.70   32.04   1653.06  37933.00   377828.6                1200
# 3      9.73    8.34    686.16   8194.00   122031.7                 165
# 4    136.60  140.20   9821.00  48260.00  1734973.5                5500
# ..      ...     ...       ...       ...        ...                 ...
# 367   87.27   85.56  10555.47  33626.25   865878.9                1100
# 368   62.78   56.45   3387.72  10646.75   606524.2                 740
# 369  101.00  101.89  13571.80  34474.50  1067772.0                 860
# 370   73.57   69.26   4756.68  21855.00   669640.3                1100
# 371   54.62   44.79   2206.19  40234.00   629797.2                 460
#
#      Actual Construction Cost
# 0                         410
# 1                        1000
# 2                         170
# 3                          30
# 4                         700
# ..                        ...
# 367                       150
# 368                        80
# 369                       220
# 370                       110
# 371                        50
#
# [372 rows x 109 columns]

# %%
# rearrange columns: make Outputs come to front for easier reading
df = pd.concat([df.iloc[:,-2],
                df.iloc[:,-1],
                df.iloc[:,0:-2]
                ],
               axis=1)
df
# Out:
#      Actual Sales Price  Actual Construction Cost  START YEAR AD  \
# 0                  2200                       410           2002
# 1                  5000                      1000           2005
# 2                  1200                       170           1999
# 3                   165                        30           1993
# 4                  5500                       700           2008
# ..                  ...                       ...            ...
# 367                1100                       150           2004
# 368                 740                        80           2002
# 369                 860                       220           2005
# 370                1100                       110           2003
# 371                 460                        50           2001
#
#      START QUARTER  COMPLETION YEAR AD  COMPLETION QUARTER  V-1     V-2  \
# 0                1                2006                   1    1  3150.0
# 1                1                2010                   4    1  7600.0
# 2                1                2002                   4    1  4800.0
# 3                2                1994                   2    1   685.0
# 4                1                2011                   2    1  3000.0
# ..             ...                 ...                 ...  ...     ...
# 367              4                2007                   1   20  1350.0
# 368              2                2003                   4   20   600.0
# 369              4                2007                   3   20  1900.0
# 370              3                2005                   4   20   510.0
# 371              1                2002                   3   20   890.0
#
#         V-3     V-4  ...  V-20.4       V-21.4   V-22.4   V-23.4  V-24.4  \
# 0     920.0   598.5  ...      15   733.800000   815.50  1755.00  8002.0
# 1    1140.0  3040.0  ...      15  1143.800000  1316.30  8364.78  8393.0
# 2     840.0   480.0  ...      15   589.500000   765.80  1755.00  4930.0
# 3     202.0    13.7  ...      12   197.679557   152.25  1442.31  1456.0
# 4     800.0  1230.0  ...      14  2220.600000  2244.10  9231.76  9286.0
# ..      ...     ...  ...     ...          ...      ...      ...     ...
# 367   350.0   108.0  ...      15  1082.500000  1176.50  8343.60  8382.0
# 368   150.0    36.0  ...      15   746.800000   815.50  1755.00  8013.0
# 369   430.0   285.0  ...      15  1424.100000  1584.30  8776.71  8799.0
# 370   160.0    30.6  ...      14   886.400000   909.20  7930.66  8004.0
# 371   230.0    35.6  ...      15   629.900000   764.50  1755.00  8420.0
#
#      V-25.4  V-26.4    V-27.4    V-28.4     V-29.4
# 0     60.74   54.26   2978.26  41407.00   601988.1
# 1     90.95   89.79  11379.37  44835.00   929027.1
# 2     38.70   32.04   1653.06  37933.00   377828.6
# 3      9.73    8.34    686.16   8194.00   122031.7
# 4    136.60  140.20   9821.00  48260.00  1734973.5
# ..      ...     ...       ...       ...        ...
# 367   87.27   85.56  10555.47  33626.25   865878.9
# 368   62.78   56.45   3387.72  10646.75   606524.2
# 369  101.00  101.89  13571.80  34474.50  1067772.0
# 370   73.57   69.26   4756.68  21855.00   669640.3
# 371   54.62   44.79   2206.19  40234.00   629797.2
#
# [372 rows x 109 columns]

# %% [markdown]
# # 2. More Check on Data

# %% [markdown]
# ## Check lag data consistency in columns

# %%
df['START YEAR AND QUARTER'] = df['START YEAR AD'].astype('string') + 'Q' + df['START QUARTER'].astype('string')
df['START YEAR AND QUARTER'] #we have a new column
# Out:
# 0      2002Q1
# 1      2005Q1
# 2      1999Q1
# 3      1993Q2
# 4      2008Q1
#         ...
# 367    2004Q4
# 368    2002Q2
# 369    2005Q4
# 370    2003Q3
# 371    2001Q1
# Name: START YEAR AND QUARTER, Length: 372, dtype: string

# %%
df['START YEAR AND QUARTER'].value_counts().sort_index() #check the "time span" and "no. of quarters" (i.e. no. of time resolutions)
# Out:
# START YEAR AND QUARTER
# 1993Q2    4
# 1993Q3    1
# 1993Q4    1
# 1994Q1    2
# 1994Q2    3
#          ..
# 2008Q4    3
# 2009Q1    3
# 2009Q2    1
# 2009Q3    1
# 2009Q4    1
# Name: count, Length: 67, dtype: Int64

# %% [markdown]
# **Finding 1: Time span: 1993Q2 to 2009Q4; No. of quarters: 67. Thus, conclude NO MISSING QUARTERS in between**<br>
# **(Explanation: 1993 to 2004 have (2004-1992)*4 = 68 quarters, leave 1993Q1 not to count we have 67, align with the result from last command)**

# %% [markdown]
# ## Check lag-data consistency across lags

# %%
df[['START YEAR AND QUARTER',
    'V-11','V-12','V-13','V-14','V-15','V-16','V-17','V-18','V-19','V-20',
    'V-21','V-22','V-23','V-24','V-25','V-26','V-27','V-28','V-29']].value_counts().sort_index()  #If we see 67 unique rows, the lag-1 data is consistent
                                                                                                  #note: value_counts() outputs a Series,
                                                                                                  #      and it do sorting by sort_index()
# Out:
# START YEAR AND QUARTER  V-11     V-12   V-13    V-14  V-15        V-16     V-17    V-18    V-19      V-20  V-21     V-22     V-23     V-24     V-25    V-26    V-27      V-28      V-29
# 1993Q2                  2580.93  12.1   10.03   1.24  38193.64    287.2    13.60   17.03   154.40    12    183.60   211.10   1612.95  1649.0   11.62   10.06   392.96    8435.75   141542.6     4
# 1993Q3                  2611.13  12.7   11.56   1.50  41015.52    373.9    14.54   34.05   308.80    12    192.60   232.90   1591.75  1601.0   11.91   10.41   363.13    16871.50  146872.1     1
# 1993Q4                  2641.34  13.1   13.09   1.11  43837.40    339.6    15.48   51.08   463.20    12    170.30   217.20   1657.66  1759.0   12.61   11.03   354.55    25307.25  155181.7     1
# 1994Q1                  2671.55  13.6   14.63   1.39  48135.00    427.3    16.42   68.10   617.60    12    207.60   255.40   1750.00  2224.0   13.77   11.66   403.50    33743.00  217000.1     2
# 1994Q2                  1818.00  14.3   16.16   1.34  47344.80    356.0    17.36   26.83   247.33    15    184.70   211.90   1750.00  2602.0   14.98   12.01   408.84    8684.50   262159.4     3
#                                                                                                                                                                                                ..
# 2008Q4                  3098.00  255.8  216.48  3.80  1704943.80  18468.3  292.40  250.58  49414.13  11    3447.80  3676.10  9967.33  10099.3  190.50  204.80  8857.00   38196.00  2310101.4    3
# 2009Q1                  3131.00  259.5  204.02  3.44  1901366.00  16139.0  276.10  334.10  65885.50  11    3499.40  3823.60  9784.77  9867.6   191.63  212.10  7966.50   50928.00  2217708.7    3
# 2009Q2                  2576.00  261.5  186.80  3.50  1970485.10  14711.0  294.47  69.12   13188.64  11    3746.01  4215.95  9833.67  9908.0   196.76  215.00  9258.40   12910.71  2183435.0    1
# 2009Q3                  2265.00  267.8  192.10  2.40  2116613.80  16335.0  306.93  138.24  26377.29  11    3962.24  4472.30  9925.49  9988.0   201.66  218.40  11479.80  25821.42  2271543.7    1
# 2009Q4                  2406.00  274.0  195.10  2.70  2171922.80  15503.0  319.38  207.36  39565.93  11    4188.65  4741.56  9916.90  9963.0   204.70  222.60  11274.90  38732.14  2606321.0    1
# Name: count, Length: 67, dtype: int64

# %%
print(df[['START YEAR AND QUARTER',
          'V-11.1','V-12.1','V-13.1','V-14.1','V-15.1','V-16.1','V-17.1','V-18.1','V-19.1','V-20.1',
          'V-21.1','V-22.1','V-23.1','V-24.1','V-25.1','V-26.1','V-27.1','V-28.1','V-29.1']].value_counts().sort_index().shape[0]) #check lag-2 data
print(df[['START YEAR AND QUARTER',
          'V-11.2','V-12.2','V-13.2','V-14.2','V-15.2','V-16.2','V-17.2','V-18.2','V-19.2','V-20.2',
          'V-21.2','V-22.2','V-23.2','V-24.2','V-25.2','V-26.2','V-27.2','V-28.2','V-29.2']].value_counts().sort_index().shape[0]) #check lag-3 data
print(df[['START YEAR AND QUARTER',
          'V-11.3','V-12.3','V-13.3','V-14.3','V-15.3','V-16.3','V-17.3','V-18.3','V-19.3','V-20.3',
          'V-21.3','V-22.3','V-23.3','V-24.3','V-25.3','V-26.3','V-27.3','V-28.3','V-29.3']].value_counts().sort_index().shape[0]) #check lag-4 data
print(df[['START YEAR AND QUARTER',
          'V-11.4','V-12.4','V-13.4','V-14.4','V-15.4','V-16.4','V-17.4','V-18.4','V-19.4','V-20.4',
          'V-21.4','V-22.4','V-23.4','V-24.4','V-25.4','V-26.4','V-27.4','V-28.4','V-29.4']].value_counts().sort_index().shape[0]) #check lag-5 data
# Out:
# 67
# 67
# 67
# 67

# %%
#we need dataframes to do further checking
df[['START YEAR AND QUARTER',
    'V-11','V-12','V-13','V-14','V-15','V-16','V-17','V-18','V-19','V-20',
    'V-21','V-22','V-23','V-24','V-25','V-26','V-27','V-28','V-29']].drop_duplicates() \
                                                                    .sort_values(by=['START YEAR AND QUARTER'],ignore_index=True)
# Out:
#    START YEAR AND QUARTER     V-11   V-12    V-13  V-14        V-15     V-16  \
# 0                  1993Q2  2580.93   12.1   10.03  1.24    38193.64    287.2
# 1                  1993Q3  2611.13   12.7   11.56  1.50    41015.52    373.9
# 2                  1993Q4  2641.34   13.1   13.09  1.11    43837.40    339.6
# 3                  1994Q1  2671.55   13.6   14.63  1.39    48135.00    427.3
# 4                  1994Q2  1818.00   14.3   16.16  1.34    47344.80    356.0
# ..                    ...      ...    ...     ...   ...         ...      ...
# 62                 2008Q4  3098.00  255.8  216.48  3.80  1704943.80  18468.3
# 63                 2009Q1  3131.00  259.5  204.02  3.44  1901366.00  16139.0
# 64                 2009Q2  2576.00  261.5  186.80  3.50  1970485.10  14711.0
# 65                 2009Q3  2265.00  267.8  192.10  2.40  2116613.80  16335.0
# 66                 2009Q4  2406.00  274.0  195.10  2.70  2171922.80  15503.0
#
#       V-17    V-18      V-19  V-20     V-21     V-22     V-23     V-24  \
# 0    13.60   17.03    154.40    12   183.60   211.10  1612.95   1649.0
# 1    14.54   34.05    308.80    12   192.60   232.90  1591.75   1601.0
# 2    15.48   51.08    463.20    12   170.30   217.20  1657.66   1759.0
# 3    16.42   68.10    617.60    12   207.60   255.40  1750.00   2224.0
# 4    17.36   26.83    247.33    15   184.70   211.90  1750.00   2602.0
# ..     ...     ...       ...   ...      ...      ...      ...      ...
# 62  292.40  250.58  49414.13    11  3447.80  3676.10  9967.33  10099.3
# 63  276.10  334.10  65885.50    11  3499.40  3823.60  9784.77   9867.6
# 64  294.47   69.12  13188.64    11  3746.01  4215.95  9833.67   9908.0
# 65  306.93  138.24  26377.29    11  3962.24  4472.30  9925.49   9988.0
# 66  319.38  207.36  39565.93    11  4188.65  4741.56  9916.90   9963.0
#
#       V-25    V-26      V-27      V-28       V-29
# 0    11.62   10.06    392.96   8435.75   141542.6
# 1    11.91   10.41    363.13  16871.50   146872.1
# 2    12.61   11.03    354.55  25307.25   155181.7
# 3    13.77   11.66    403.50  33743.00   217000.1
# 4    14.98   12.01    408.84   8684.50   262159.4
# ..     ...     ...       ...       ...        ...
# 62  190.50  204.80   8857.00  38196.00  2310101.4
# 63  191.63  212.10   7966.50  50928.00  2217708.7
# 64  196.76  215.00   9258.40  12910.71  2183435.0
# 65  201.66  218.40  11479.80  25821.42  2271543.7
# 66  204.70  222.60  11274.90  38732.14  2606321.0
#
# [67 rows x 20 columns]

# %%
#repeat last step to create 5 lag-data dataframes
lag1_df = df[['START YEAR AND QUARTER',
              'V-11','V-12','V-13','V-14','V-15','V-16','V-17','V-18','V-19','V-20',
              'V-21','V-22','V-23','V-24','V-25','V-26','V-27','V-28','V-29']].drop_duplicates() \
                                                                              .sort_values(by=['START YEAR AND QUARTER'],ignore_index=True)
lag2_df = df[['START YEAR AND QUARTER',
              'V-11.1','V-12.1','V-13.1','V-14.1','V-15.1','V-16.1','V-17.1','V-18.1','V-19.1','V-20.1',
              'V-21.1','V-22.1','V-23.1','V-24.1','V-25.1','V-26.1','V-27.1','V-28.1','V-29.1']].drop_duplicates() \
                                                                              .sort_values(by=['START YEAR AND QUARTER'],ignore_index=True)
lag3_df = df[['START YEAR AND QUARTER',
              'V-11.2','V-12.2','V-13.2','V-14.2','V-15.2','V-16.2','V-17.2','V-18.2','V-19.2','V-20.2',
              'V-21.2','V-22.2','V-23.2','V-24.2','V-25.2','V-26.2','V-27.2','V-28.2','V-29.2']].drop_duplicates() \
                                                                              .sort_values(by=['START YEAR AND QUARTER'],ignore_index=True)
lag4_df = df[['START YEAR AND QUARTER',
              'V-11.3','V-12.3','V-13.3','V-14.3','V-15.3','V-16.3','V-17.3','V-18.3','V-19.3','V-20.3',
              'V-21.3','V-22.3','V-23.3','V-24.3','V-25.3','V-26.3','V-27.3','V-28.3','V-29.3']].drop_duplicates() \
                                                                              .sort_values(by=['START YEAR AND QUARTER'],ignore_index=True)
lag5_df = df[['START YEAR AND QUARTER',
              'V-11.4','V-12.4','V-13.4','V-14.4','V-15.4','V-16.4','V-17.4','V-18.4','V-19.4','V-20.4',
              'V-21.4','V-22.4','V-23.4','V-24.4','V-25.4','V-26.4','V-27.4','V-28.4','V-29.4']].drop_duplicates() \
                                                                              .sort_values(by=['START YEAR AND QUARTER'],ignore_index=True)

# %%
#compare V11 first
pd.concat([lag1_df.iloc[:-4,0:2],
           lag2_df.iloc[1:-3,0:2],
           lag3_df.iloc[2:-2,0:2],
           lag4_df.iloc[3:-1,0:2],
           lag5_df.iloc[4:,0:2]], axis=1)
# Out:
#    START YEAR AND QUARTER     V-11 START YEAR AND QUARTER   V-11.1  \
# 0                  1993Q2  2580.93                   <NA>      NaN
# 1                  1993Q3  2611.13                 1993Q3  2580.93
# 2                  1993Q4  2641.34                 1993Q4  2611.13
# 3                  1994Q1  2671.55                 1994Q1  2641.34
# 4                  1994Q2  1818.00                 1994Q2  2671.55
# ..                    ...      ...                    ...      ...
# 62                 2008Q4  3098.00                 2008Q4  4242.00
# 63                   <NA>      NaN                 2009Q1  3098.00
# 64                   <NA>      NaN                   <NA>      NaN
# 65                   <NA>      NaN                   <NA>      NaN
# 66                   <NA>      NaN                   <NA>      NaN
#
#    START YEAR AND QUARTER   V-11.2 START YEAR AND QUARTER   V-11.3  \
# 0                    <NA>      NaN                   <NA>      NaN
# 1                    <NA>      NaN                   <NA>      NaN
# 2                  1993Q4  2580.93                   <NA>      NaN
# 3                  1994Q1  2611.13                 1994Q1  2580.93
# 4                  1994Q2  2641.34                 1994Q2  2611.13
# ..                    ...      ...                    ...      ...
# 62                 2008Q4  6458.00                 2008Q4  6790.00
# 63                 2009Q1  4242.00                 2009Q1  6458.00
# 64                 2009Q2  3098.00                 2009Q2  4242.00
# 65                   <NA>      NaN                 2009Q3  3098.00
# 66                   <NA>      NaN                   <NA>      NaN
#
#    START YEAR AND QUARTER   V-11.4
# 0                    <NA>      NaN
# 1                    <NA>      NaN
# 2                    <NA>      NaN
# 3                    <NA>      NaN
# 4                  1994Q2  2580.93
# ..                    ...      ...
# 62                 2008Q4  6370.00
# 63                 2009Q1  6790.00
# 64                 2009Q2  6458.00
# 65                 2009Q3  4242.00
# 66                 2009Q4  3098.00
#
# [67 rows x 10 columns]

# %%
#we can use reset_index() to make V11.x across lag-data1,2,3,4,5 align
pd.concat([lag1_df.iloc[:-4,0:2].reset_index(),
           lag2_df.iloc[1:-3,0:2].reset_index(),
           lag3_df.iloc[2:-2,0:2].reset_index(),
           lag4_df.iloc[3:-1,0:2].reset_index(),
           lag5_df.iloc[4:,0:2].reset_index()],
           axis=1)
# Out:
#     index START YEAR AND QUARTER     V-11  index START YEAR AND QUARTER  \
# 0       0                 1993Q2  2580.93      1                 1993Q3
# 1       1                 1993Q3  2611.13      2                 1993Q4
# 2       2                 1993Q4  2641.34      3                 1994Q1
# 3       3                 1994Q1  2671.55      4                 1994Q2
# 4       4                 1994Q2  1818.00      5                 1994Q3
# ..    ...                    ...      ...    ...                    ...
# 58     58                 2007Q4  6370.00     59                 2008Q1
# 59     59                 2008Q1  6790.00     60                 2008Q2
# 60     60                 2008Q2  6458.00     61                 2008Q3
# 61     61                 2008Q3  4242.00     62                 2008Q4
# 62     62                 2008Q4  3098.00     63                 2009Q1
#
#      V-11.1  index START YEAR AND QUARTER   V-11.2  index  \
# 0   2580.93      2                 1993Q4  2580.93      3
# 1   2611.13      3                 1994Q1  2611.13      4
# 2   2641.34      4                 1994Q2  2641.34      5
# 3   2671.55      5                 1994Q3  2671.55      6
# 4   1818.00      6                 1994Q4  1818.00      7
# ..      ...    ...                    ...      ...    ...
# 58  6370.00     60                 2008Q2  6370.00     61
# 59  6790.00     61                 2008Q3  6790.00     62
# 60  6458.00     62                 2008Q4  6458.00     63
# 61  4242.00     63                 2009Q1  4242.00     64
# 62  3098.00     64                 2009Q2  3098.00     65
#
#    START YEAR AND QUARTER   V-11.3  index START YEAR AND QUARTER   V-11.4
# 0                  1994Q1  2580.93      4                 1994Q2  2580.93
# 1                  1994Q2  2611.13      5                 1994Q3  2611.13
# 2                  1994Q3  2641.34      6                 1994Q4  2641.34
# 3                  1994Q4  2671.55      7                 1995Q1  2671.55
# 4                  1995Q1  1818.00      8                 1995Q2  1818.00
# ..                    ...      ...    ...                    ...      ...
# 58                 2008Q3  6370.00     62                 2008Q4  6370.00
# 59                 2008Q4  6790.00     63                 2009Q1  6790.00
# 60                 2009Q1  6458.00     64                 2009Q2  6458.00
# 61                 2009Q2  4242.00     65                 2009Q3  4242.00
# 62                 2009Q3  3098.00     66                 2009Q4  3098.00
#
# [63 rows x 15 columns]

# %%
#make all lag-data dataframe has the same column-index, such that we can COMPARE V11 to V29 in one go
lag1_df.columns = lag1_df.columns.str[0:]+'.x';
lag1_df.columns = lag1_df.columns.str.replace('START YEAR AND QUARTER.x','START YEAR AND QUARTER')
lag2_df.columns = lag2_df.columns.str.replace('.1','.x')
lag3_df.columns = lag3_df.columns.str.replace('.2','.x')
lag4_df.columns = lag4_df.columns.str.replace('.3','.x')
lag5_df.columns = lag5_df.columns.str.replace('.4','.x')
print(lag1_df.columns)
print(lag2_df.columns)
print(lag3_df.columns)
print(lag4_df.columns)
print(lag5_df.columns)
# Out:
# Index(['START YEAR AND QUARTER', 'V-11.x', 'V-12.x', 'V-13.x', 'V-14.x',
#        'V-15.x', 'V-16.x', 'V-17.x', 'V-18.x', 'V-19.x', 'V-20.x', 'V-21.x',
#        'V-22.x', 'V-23.x', 'V-24.x', 'V-25.x', 'V-26.x', 'V-27.x', 'V-28.x',
#        'V-29.x'],
#       dtype='object')
# Index(['START YEAR AND QUARTER', 'V-11.x', 'V-12.x', 'V-13.x', 'V-14.x',
#        'V-15.x', 'V-16.x', 'V-17.x', 'V-18.x', 'V-19.x', 'V-20.x', 'V-21.x',
#        'V-22.x', 'V-23.x', 'V-24.x', 'V-25.x', 'V-26.x', 'V-27.x', 'V-28.x',
#        'V-29.x'],
#       dtype='object')
# Index(['START YEAR AND QUARTER', 'V-11.x', 'V-12.x', 'V-13.x', 'V-14.x',
#        'V-15.x', 'V-16.x', 'V-17.x', 'V-18.x', 'V-19.x', 'V-20.x', 'V-21.x',
#        'V-22.x', 'V-23.x', 'V-24.x', 'V-25.x', 'V-26.x', 'V-27.x', 'V-28.x',
#        'V-29.x'],
#       dtype='object')
# Index(['START YEAR AND QUARTER', 'V-11.x', 'V-12.x', 'V-13.x', 'V-14.x',
#        'V-15.x', 'V-16.x', 'V-17.x', 'V-18.x', 'V-19.x', 'V-20.x', 'V-21.x',
#        'V-22.x', 'V-23.x', 'V-24.x', 'V-25.x', 'V-26.x', 'V-27.x', 'V-28.x',
#        'V-29.x'],
#       dtype='object')
# Index(['START YEAR AND QUARTER', 'V-11.x', 'V-12.x', 'V-13.x', 'V-14.x',
#        'V-15.x', 'V-16.x', 'V-17.x', 'V-18.x', 'V-19.x', 'V-20.x', 'V-21.x',
#        'V-22.x', 'V-23.x', 'V-24.x', 'V-25.x', 'V-26.x', 'V-27.x', 'V-28.x',
#        'V-29.x'],
#       dtype='object')

# %%
lag1_df.iloc[:-4,0:2].reset_index()
# Out:
#     index START YEAR AND QUARTER   V-11.x
# 0       0                 1993Q2  2580.93
# 1       1                 1993Q3  2611.13
# 2       2                 1993Q4  2641.34
# 3       3                 1994Q1  2671.55
# 4       4                 1994Q2  1818.00
# ..    ...                    ...      ...
# 58     58                 2007Q4  6370.00
# 59     59                 2008Q1  6790.00
# 60     60                 2008Q2  6458.00
# 61     61                 2008Q3  4242.00
# 62     62                 2008Q4  3098.00
#
# [63 rows x 3 columns]

# %%
#check V11-V29 align across lag1 and lag2
lag1_df.iloc[:-4,].reset_index().drop(columns=['index','START YEAR AND QUARTER']) == lag2_df.iloc[1:-3,].reset_index().drop(columns=['index','START YEAR AND QUARTER'])
# Out:
#     V-11.x  V-12.x  V-13.x  V-14.x  V-15.x  V-16.x  V-17.x  V-18.x  V-19.x  \
# 0     True    True    True    True    True    True    True    True    True
# 1     True    True    True    True    True    True    True    True    True
# 2     True    True    True    True    True    True    True    True    True
# 3     True    True    True    True    True    True    True    True    True
# 4     True    True    True    True    True    True    True    True    True
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 58    True    True    True    True    True    True    True    True    True
# 59    True    True    True    True    True    True    True    True    True
# 60    True    True    True    True    True    True    True    True    True
# 61    True    True    True    True    True    True    True    True    True
# 62    True    True    True    True    True    True    True    True    True
#
#     V-20.x  V-21.x  V-22.x  V-23.x  V-24.x  V-25.x  V-26.x  V-27.x  V-28.x  \
# 0     True    True    True    True    True    True    True    True    True
# 1     True    True    True    True    True    True    True    True    True
# 2     True    True    True    True    True    True    True    True    True
# 3     True    True    True    True    True    True    True    True    True
# 4     True    True    True    True    True    True    True    True    True
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 58    True    True    True    True    True    True    True    True    True
# 59    True    True    True    True    True    True    True    True    True
# 60    True    True    True    True    True    True    True    True    True
# 61    True    True    True    True    True    True    True    True    True
# 62    True    True    True    True    True    True    True    True    True
#
#     V-29.x
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# ..     ...
# 58    True
# 59    True
# 60    True
# 61    True
# 62    True
#
# [63 rows x 19 columns]

# %%
print((lag1_df.iloc[:-4,].reset_index().drop(columns=['index','START YEAR AND QUARTER']) == lag2_df.iloc[1:-3,].reset_index().drop(columns=['index','START YEAR AND QUARTER'])).sum().sum())
print((lag2_df.iloc[1:-3,].reset_index().drop(columns=['index','START YEAR AND QUARTER']) == lag3_df.iloc[2:-2,].reset_index().drop(columns=['index','START YEAR AND QUARTER'])).sum().sum())
print((lag3_df.iloc[2:-2,].reset_index().drop(columns=['index','START YEAR AND QUARTER']) == lag4_df.iloc[3:-1,].reset_index().drop(columns=['index','START YEAR AND QUARTER'])).sum().sum())
print((lag4_df.iloc[3:-1,].reset_index().drop(columns=['index','START YEAR AND QUARTER']) == lag5_df.iloc[4:,].reset_index().drop(columns=['index','START YEAR AND QUARTER'])).sum().sum())
print(f"Comparison dataframe has this no. of cells in total: {63*19}")
# Out:
# 1197
# 1197
# 1197
# 1197
# Comparison dataframe has this no. of cells in total: 1197

# %% [markdown]
# **Findings: Econ metrices of different lag-data align across different lags.Together with consistency in each columns (checked in last part), lag-data are ALL CONSISTENT**

# %% [markdown]
# ## Construction of a **no-lag** economic time-series dataset

# %%
lag1_df.loc[0:65,] #intermediate result
# Out:
#    START YEAR AND QUARTER   V-11.x  V-12.x  V-13.x  V-14.x      V-15.x  \
# 0                  1993Q2  2580.93    12.1   10.03    1.24    38193.64
# 1                  1993Q3  2611.13    12.7   11.56    1.50    41015.52
# 2                  1993Q4  2641.34    13.1   13.09    1.11    43837.40
# 3                  1994Q1  2671.55    13.6   14.63    1.39    48135.00
# 4                  1994Q2  1818.00    14.3   16.16    1.34    47344.80
# ..                    ...      ...     ...     ...     ...         ...
# 61                 2008Q3  4242.00   245.1  225.00    6.54  1670609.20
# 62                 2008Q4  3098.00   255.8  216.48    3.80  1704943.80
# 63                 2009Q1  3131.00   259.5  204.02    3.44  1901366.00
# 64                 2009Q2  2576.00   261.5  186.80    3.50  1970485.10
# 65                 2009Q3  2265.00   267.8  192.10    2.40  2116613.80
#
#      V-16.x  V-17.x  V-18.x    V-19.x  V-20.x   V-21.x   V-22.x   V-23.x  \
# 0     287.2   13.60   17.03    154.40      12   183.60   211.10  1612.95
# 1     373.9   14.54   34.05    308.80      12   192.60   232.90  1591.75
# 62  65885.50      11  3499.40  3823.60  9784.77   9867.6  191.63  212.10
# 63  13188.64      11  3746.01  4215.95  9833.67   9908.0  196.76  215.00
# 64  26377.29      11  3962.24  4472.30  9925.49   9988.0  201.66  218.40
# 65  39565.93      11  4188.65  4741.56  9916.90   9963.0  204.70  222.60
#
#       V-27.x    V-28.x     V-29.x
# 0     363.13  16871.50   146872.1
# 1     354.55  25307.25   155181.7
# 2     403.50  33743.00   217000.1
# 3     408.84   8684.50   262159.4
# 4     450.34  17369.00   268843.7
# ..       ...       ...        ...
# 61   8857.00  38196.00  2310101.4
# 62   7966.50  50928.00  2217708.7
# 63   9258.40  12910.71  2183435.0
# 64  11479.80  25821.42  2271543.7
# 65  11274.90  38732.14  2606321.0
#
# [66 rows x 19 columns]

# %%
lag0_df = pd.concat([lag1_df.loc[0:65,'START YEAR AND QUARTER'],
                     lag1_df.loc[1:,].reset_index().drop(columns=['index','START YEAR AND QUARTER'])],
                    axis=1)
lag0_df
# Out:
#    START YEAR AND QUARTER   V-11.x  V-12.x  V-13.x  V-14.x      V-15.x  \
# 0                  1993Q2  2611.13    12.7   11.56    1.50    41015.52
# 1                  1993Q3  2641.34    13.1   13.09    1.11    43837.40
# 2                  1993Q4  2671.55    13.6   14.63    1.39    48135.00
# 3                  1994Q1  1818.00    14.3   16.16    1.34    47344.80
# 4                  1994Q2  2197.00    15.5   17.69    1.67    52148.60
# ..                    ...      ...     ...     ...     ...         ...
# 61                 2008Q3  3098.00   255.8  216.48    3.80  1704943.80
# 62                 2008Q4  3131.00   259.5  204.02    3.44  1901366.00
# 63                 2009Q1  2576.00   261.5  186.80    3.50  1970485.10
# 64                 2009Q2  2265.00   267.8  192.10    2.40  2116613.80
# 65                 2009Q3  2406.00   274.0  195.10    2.70  2171922.80
#
#      V-16.x  V-17.x  V-18.x    V-19.x  V-20.x   V-21.x   V-22.x   V-23.x  \
# 0     373.9   14.54   34.05    308.80      12   192.60   232.90  1591.75
# 1     339.6   15.48   51.08    463.20      12   170.30   217.20  1657.66
# 2     427.3   16.42   68.10    617.60      12   207.60   255.40  1750.00
# 3     356.0   17.36   26.83    247.33      15   184.70   211.90  1750.00
# 4     417.7   18.30   53.65    494.65      15   202.80   260.40  1750.00
# ..      ...     ...     ...       ...     ...      ...      ...      ...
# 61  18468.3  292.40  250.58  49414.13      11  3447.80  3676.10  9967.33
# 62  16139.0  276.10  334.10  65885.50      11  3499.40  3823.60  9784.77
# 63  14711.0  294.47   69.12  13188.64      11  3746.01  4215.95  9833.67
# 64  16335.0  306.93  138.24  26377.29      11  3962.24  4472.30  9925.49
# 65  15503.0  319.38  207.36  39565.93      11  4188.65  4741.56  9916.90
#
#      V-24.x  V-25.x  V-26.x    V-27.x    V-28.x     V-29.x
# 0    1601.0   11.91   10.41    363.13  16871.50   146872.1
# 1    1759.0   12.61   11.03    354.55  25307.25   155181.7
# 2    2224.0   13.77   11.66    403.50  33743.00   217000.1
# 3    2602.0   14.98   12.01    408.84   8684.50   262159.4
lag0_df.to_pickle('lag0_standalone.pkl')
lag0_df.to_csv('lag0_standalone.csv')

# %% [markdown]
# **Note: Can collect .pkl or .csv file or continue using *lag0_df* in this notebook**

# %% [markdown]
# ## Looking into the no-lag economic metrices

# %% [markdown]
# ###Basic Plot

# %%
#Basic Plot
lag0_df_basic = lag0_df.set_index('START YEAR AND QUARTER')
lag0_df_basic.iloc[:,:].plot(figsize=(12, 6))
plt.title('Economic Metrices Over Time')
plt.xlabel('Time')
plt.ylabel('Exact Values')
plt.legend(title='Metrices')
plt.show()

# %% [markdown]
# **Findings: Scale stretch from 0 up to 2.5x10e6 (need to look at a different plot) to see pattern; V-29 and V-15 stand out, they are ... (to be completed)**

# %% [markdown]
# ###Plot by quarter-over-quarter ratio [not useful]

# %%
#Plot comparing current quarter with last quarter
lag0_df_versusLast = lag0_df.iloc[:,1:] # copy without the first col
lag0_df_versusLast = lag0_df_versusLast.iloc[1:,].reset_index()/lag0_df_versusLast.iloc[:-1,].reset_index()
lag0_df_versusLast = lag0_df_versusLast.drop(columns=['index'])
lag0_df_versusLast = pd.concat([lag0_df.iloc[1:,0].reset_index(),lag0_df_versusLast],axis=1).drop(columns=['index'])
lag0_df_versusLast = lag0_df_versusLast.set_index('START YEAR AND QUARTER')
lag0_df_versusLast
# Out:
#                           V-11.0    V-12.0    V-13.0    V-14.0    V-15.0  \
# START YEAR AND QUARTER
# 1993Q3                  1.011570  1.031496  1.132353  0.740000  1.068800
# 1993Q4                  1.011437  1.038168  1.117647  1.252252  1.098035
# 1994Q1                  0.680504  1.051471  1.104580  0.964029  0.983584
# 1994Q2                  1.208471  1.083916  1.094678  1.246269  1.101464
# 1994Q3                  0.710970  1.083871  1.086490  0.904192  1.072704
# ...                          ...       ...       ...       ...       ...
# 2008Q3                  0.730316  1.043656  0.962133  0.581040  1.020552
# 2008Q4                  1.010652  1.014464  0.942443  0.905263  1.115207
# 2009Q1                  0.822740  1.007707  0.915597  1.017442  1.036352
# 2009Q2                  0.879270  1.024092  1.028373  0.685714  1.074159
# 2009Q3                  1.062252  1.023152  1.015617  1.125000  1.026131
#
#                           V-16.0    V-17.0    V-18.0    V-19.0  V-20.0  \
# START YEAR AND QUARTER
# 1993Q3                  0.908264  1.064649  1.500147  1.500000    1.00
# 1993Q4                  1.258245  1.060724  1.333203  1.333333    1.00
# 1994Q1                  0.833138  1.057247  0.393979  0.400470    1.25
# 1994Q2                  1.173315  1.054147  1.999627  1.999960    1.00
# 1994Q3                  1.184103  1.050820  1.500093  1.500010    1.00
# ...                          ...       ...       ...       ...     ...
# 2008Q3                  0.988090  0.973045  1.500030  1.500000    1.00
# 2008Q4                  0.873876  0.944254  1.333307  1.333333    1.00
# 2009Q1                  0.911519  1.066534  0.206884  0.200175    1.00
# 2009Q2                  1.110394  1.042313  2.000000  2.000001    1.00
# 2009Q3                  0.949066  1.040563  1.500000  1.500000    1.00
#
#                           V-21.0    V-22.0    V-23.0    V-24.0    V-25.0  \
# START YEAR AND QUARTER
# 1993Q3                  0.884216  0.932589  1.041407  1.098688  1.058774
# 1993Q4                  1.219025  1.175875  1.055705  1.264355  1.091990
# 1994Q1                  0.889692  0.829679  1.000000  1.169964  1.087872
# 1994Q2                  1.097997  1.228882  1.000000  0.943505  1.058077
# 1994Q3                  1.098126  1.108295  1.000000  1.094501  1.087066
# ...                          ...       ...       ...       ...       ...
# 2008Q3                  1.027415  0.997233  1.059951  1.064305  1.058569
# 2008Q4                  1.014966  1.040124  0.981684  0.977058  1.005932
# 2009Q1                  1.070472  1.102613  1.004998  1.004094  1.026770
# 2009Q2                  1.057723  1.060805  1.009337  1.008074  1.024903
# 2009Q3                  1.057142  1.060206  0.999135  0.997497  1.015075
#
#                           V-26.0    V-27.0    V-28.0    V-29.0
# START YEAR AND QUARTER
# 1993Q3                  1.059558  0.976372  1.500000  1.056577
# 1993Q4                  1.057117  1.138062  1.333333  1.398361
# 1994Q1                  1.030017  1.013234  0.257372  1.208107
# 1994Q2                  1.044130  1.101507  2.000000  1.025497
# 1994Q3                  1.066188  1.249789  1.500000  1.039757
# ...                          ...       ...       ...       ...
# 2008Q3                  1.080739  0.752954  1.500000  1.002975
# 2008Q4                  1.035645  0.899458  1.333333  0.960005
# 2009Q1                  1.013673  1.162167  0.253509  0.984545
# 2009Q2                  1.015814  1.239933  2.000000  1.040353
# 2009Q3                  1.019231  0.982151  1.500000  1.147379
#
# [65 rows x 19 columns]

# %%
lag0_df_versusLast.plot(figsize=(12, 6))
plt.title('Economic Indices % Change Over Time')
plt.xlabel('Time Intervals')
plt.ylabel('% Change')
plt.legend(title='Indices')
plt.show()

# %% [markdown]
# **Findings: From V-19, we sees a repetitive pattern in a 4 quarter-cycle; From V-23, ... (to be completed)**

# %% [markdown]
# ### Plot by quarter-over-quarter **log-ratio** [not useful]

# %%
lag0_df_vLastTakeLog = lag0_df_versusLast.applymap(lambda x: np.log(x))
lag0_df_vLastTakeLog
# Out:
# C:\Users\leuk\AppData\Local\Temp\ipykernel_12812\3988582971.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   lag0_df_vLastTakeLog = lag0_df_versusLast.applymap(lambda x: np.log(x))
#                           V-11.0    V-12.0    V-13.0    V-14.0    V-15.0  \
# START YEAR AND QUARTER
# 1993Q3                  0.011503  0.031010  0.124298 -0.301105  0.066537
# 1993Q4                  0.011372  0.037458  0.111226  0.224944  0.093522
# 1994Q1                 -0.384922  0.050190  0.099465 -0.036634 -0.016553
# 1994Q2                  0.189356  0.080580  0.090460  0.220154  0.096640
# 1994Q3                 -0.341126  0.080539  0.082952 -0.100714  0.070182
# ...                          ...       ...       ...       ...       ...
# 2008Q3                 -0.314278  0.042730 -0.038602 -0.542936  0.020344
# 2008Q4                  0.010596  0.014361 -0.059280 -0.099530  0.109040
# 2009Q1                 -0.195115  0.007678 -0.088180  0.017291  0.035707
# 2009Q2                 -0.128663  0.023806  0.027978 -0.377294  0.071538
# 2009Q3                  0.060391  0.022888  0.015496  0.117783  0.025795
#
#                           V-16.0    V-17.0    V-18.0    V-19.0    V-20.0  \
# START YEAR AND QUARTER
# 1993Q3                 -0.096220  0.062645  0.405563  0.405465  0.000000
# 1993Q4                  0.229718  0.058951  0.287584  0.287682  0.000000
# 1994Q1                 -0.182556  0.055669 -0.931457 -0.915118  0.223144
# 1994Q2                  0.159833  0.052732  0.692961  0.693127  0.000000
# 1994Q3                  0.168986  0.049570  0.405527  0.405472  0.000000
# ...                          ...       ...       ...       ...       ...
# 2008Q3                 -0.011981 -0.027325  0.405485  0.405465  0.000000
# 2008Q4                 -0.134817 -0.057360  0.287662  0.287682  0.000000
# 2009Q1                 -0.092643  0.064414 -1.575596 -1.608563  0.000000
# 2009Q2                  0.104715  0.041443  0.693147  0.693148  0.000000
# 2009Q3                 -0.052276  0.039762  0.405465  0.405465  0.000000
#
#                           V-21.0    V-22.0    V-23.0    V-24.0    V-25.0  \
# START YEAR AND QUARTER
# 1993Q3                 -0.123054 -0.069791  0.040573  0.094117  0.057112
# 1993Q4                  0.198052  0.162012  0.054209  0.234562  0.088002
# 1994Q1                 -0.116880 -0.186716  0.000000  0.156973  0.084224
# 1994Q2                  0.093487  0.206104  0.000000 -0.058154  0.056454
# 1994Q3                  0.093605  0.102823  0.000000  0.090299  0.083483
# ...                          ...       ...       ...       ...       ...
# 2008Q3                  0.027046 -0.002771  0.058222  0.062322  0.056918
# 2008Q4                  0.014855  0.039340 -0.018486 -0.023209  0.005914
# 2009Q1                  0.068100  0.097683  0.004985  0.004086  0.026418
# 2009Q2                  0.056118  0.059028  0.009294  0.008042  0.024598
# 2009Q3                  0.055569  0.058463 -0.000866 -0.002506  0.014962
#
#                           V-26.0    V-27.0    V-28.0    V-29.0
# START YEAR AND QUARTER
# 1993Q3                  0.057852 -0.023912  0.405465  0.055035
# 1993Q4                  0.055545  0.129327  0.287682  0.335301
# 1994Q1                  0.029575  0.013147 -1.357233  0.189055
# 1994Q2                  0.043184  0.096679  0.693147  0.025177
# 1994Q3                  0.064090  0.222975  0.405465  0.038987
# ...                          ...       ...       ...       ...
# 2008Q3                  0.077645 -0.283751  0.405465  0.002971
# 2008Q4                  0.035024 -0.105963  0.287682 -0.040817
# 2009Q1                  0.013580  0.150286 -1.372356 -0.015575
# 2009Q2                  0.015690  0.215058  0.693147  0.039560
# 2009Q3                  0.019048 -0.018010  0.405465  0.137480
#
# [65 rows x 19 columns]

# %%
lag0_df_vLastTakeLog.iloc[:,:].plot(figsize=(12, 6))
plt.title('Economic Metrices (taking 1993Q2 as 1.0) Over Time')
plt.xlabel('Time')
plt.ylabel('Log-ratio versus Last Quarter')
plt.legend(title='Log-ratio')
plt.show()

# %% [markdown]
# **(No further findings)**

# %% [markdown]
# ###Plot with reference to 1993Q2 (denoted as *Quarter0* )

# %%
#Plot comparing current quarter with "Quarter0" (1993Q2)
lag0_df_refQ0 = lag0_df.set_index('START YEAR AND QUARTER')
lag0_df_refQ0 = lag0_df_refQ0/lag0_df_refQ0.iloc[0,]
lag0_df_refQ0
# Out:
#                           V-11.0     V-12.0     V-13.0    V-14.0     V-15.0  \
# START YEAR AND QUARTER
# %%
lag0_df_refQ0.to_pickle('lag0_df_refQ0.pkl')
lag0_df_refQ0.to_csv('lag0_df_refQ0.csv')

# %%
'''
V-19 (col8) variates upto 2X000%

V-15,16,27 (i.e. col4,5,16) variates upto 5000%

V-12 (col1), V-13 (col2), V-17 (col6),
V-21 (col10), V-22 (col-11), V-25 (col14), V-26 (col15), V-29 (col18) are variating up to 5000%

others variate within 1000%
'''
# Out:
# '\nV-19 (col8) variates upto 2X000%\n\nV-15,16,27 (i.e. col4,5,16) variates upto 5000%\n\nV-12 (col1), V-13 (col2), V-17 (col6),\nV-21 (col10), V-22 (col-11), V-25 (col14), V-26 (col15), V-29 (col18) are variating up to 5000%\n\nothers variate within 1000%\n'

# %%
lag0_df_refQ0.loc[:,'V-19.0'].plot(figsize=(12, 6))
#V-19: Amount of loans extended by banks in a quarter (in $10m)
plt.title('Unit Gold Price (taking 1993Q2 as 1.0) Over Time')
plt.xlabel('Time')
plt.ylabel('Ratio of Current-value : 1993Q2-value')
plt.legend(title='Ratio')
plt.show()

# %%
lag0_df_refQ0.loc[:,['V-15.0','V-16.0','V-27.0']].plot(figsize=(12, 6))
#V-15: Cumulative Liquidity (in $10m)
#V-16: Private Sector investment in new buildings (in $10m)
#V-27: Stock market index
plt.title('Economic Metrices (taking 1993Q2 as 1.0) Over Time')
plt.xlabel('Time')
plt.ylabel('Ratio of Current-value : 1993Q2-value')
plt.legend(title='Ratio')
plt.show()

# %%
lag0_df_refQ0.loc[:,['V-12.0','V-13.0','V-14.0','V-17.0','V-21.0','V-22.0','V-25.0','V-26.0','V-29.0']].plot(figsize=(12, 6))
#mid variation metrices only
#V-12: Building Service Index (base year: 1966) ** See "Note: For "Index"-type of econ data, base-year changing is JUST a change of scale"
#V-13: Wholesales Price Index (base year: 1966)
#V-14: Total floor areas permitted by city municipality (in sq. metre)
#V-17: Land Price Index (base year: 1966)
#V-21: Average construction cost of buildings by private sector at the time of completion of construction
#V-22: Average construction cost of buildings by private sector at the beginning of the construction
#V-25: Consumer price index (CPI) (base year: 1966)
#V-26: CPI of housing, water, fuel & power (base year: 1966)
#V-29: Unit Gold Price (in $)
plt.title('Economic Metrices (taking 1993Q2 as 1.0) Over Time')
plt.xlabel('Time')
plt.ylabel('Ratio of Current-value : 1993Q2-value')
plt.legend(title='Ratio')
plt.show()

# %%
lag0_df_refQ0.loc[:,['V-18.0','V-23.0','V-24.0']].plot(figsize=(12, 6)) #relatively low movement metrices
#V-18: Number of loans extended by banks in a quarter (in integer)
#V-23: Official Exchange Rate (in ?IRR = 1 USD)
#V-24: Nonofficial (street market) exchange rate (in ?IRR = 1 USD)
plt.title('Economic Metrices (taking 1993Q2 as 1.0) Over Time')
plt.xlabel('Time')
plt.ylabel('Ratio of Current-value : 1993Q2-value')
plt.legend(title='Ratio')
plt.show()

# %%
lag0_df_refQ0.loc[:,['V-11.0','V-20.0','V-28.0']].plot(figsize=(12, 6)) #low movement metrices
plt.title('Economic Metrices (taking 1993Q2 as 1.0) Over Time')
#V-11: Number of building permits issued
#V-20: Interest rate (in %)
#V-28: Population of Tehran
plt.xlabel('Time')
plt.ylabel('Ratio of Current-value : 1993Q2-value')
plt.legend(title='Ratio')
plt.show()

# %% [markdown]
# **Findings:**

# %% [markdown]
# #### **Note: For "Index"-type of econ data, base-year changing is JUST a change of scale

# %%
plt.figure(figsize=(12, 6))
plt.plot(lag0_df_refQ0.loc[:,['V-12.0']].index,lag0_df_refQ0.loc[:,['V-12.0']], label="V-12.0 ref 1993Q2")
plt.plot(lag0_df_basic.loc[:,['V-12.0']].index,lag0_df_basic.loc[:,['V-12.0']], label="V-12.0 ref 1966")

plt.title('Economic Metrices (taking different year as bases) Over Time')
plt.xlabel('Time')
plt.ylabel('Ratio of Current-value : baseYear-value')
plt.legend(title='Ratio')
plt.show()

# %%
lag0_df_refQ0.loc[:,['V-12.0']].plot(figsize=(12, 6),color='orange')
plt.title('Economic Metrices (taking 1993Q2 as 1.0) Over Time')
plt.xlabel('Time')
plt.ylabel('Ratio of Current-value : 1993Q2-value')
plt.legend(title='Ratio')
plt.show()

# %%
lag0_df_basic.loc[:,['V-12.0']].plot(figsize=(12, 6))
plt.title('Economic Metrices (taking 1966 as 1.0) Over Time')
plt.xlabel('Time')
plt.ylabel('Ratio of Current-value : 1966-value')
plt.legend(title='Ratio')
plt.show()

# %% [markdown]
# ### Prepare an all-in-one dataframe for later use

# %%
df_lag012345 = pd.merge(df,lag0_df, how='left')
df_lag012345
# Out:
#      Actual Sales Price  Actual Construction Cost  START YEAR AD  \
# 0                  2200                       410           2002
# 1                  5000                      1000           2005
# 2                  1200                       170           1999
# 3                   165                        30           1993
# 4                  5500                       700           2008
# ..                  ...                       ...            ...
# 367                1100                       150           2004
# 368                 740                        80           2002
# 369                 860                       220           2005
# 370                1100                       110           2003
# 371                 460                        50           2001
#
#      START QUARTER  COMPLETION YEAR AD  COMPLETION QUARTER  V-1     V-2  \
# 0                1                2006                   1    1  3150.0
# 1                1                2010                   4    1  7600.0
# 2                1                2002                   4    1  4800.0
# 3                2                1994                   2    1   685.0
# 4                1                2011                   2    1  3000.0
# ..             ...                 ...                 ...  ...     ...
# 367              4                2007                   1   20  1350.0
# 368              2                2003                   4   20   600.0
# 369              4                2007                   3   20  1900.0
# 370              3                2005                   4   20   510.0
# 371              1                2002                   3   20   890.0
#
#         V-3     V-4  ...  V-20.0  V-21.0  V-22.0   V-23.0  V-24.0  V-25.0  \
# 0     920.0   598.5  ...    14.0   831.8   938.4  7924.48  7994.0   71.56
# 1    1140.0  3040.0  ...    15.0  1836.6  1932.5  8920.04  8938.0  110.51
# 2     840.0   480.0  ...    15.0   641.5   652.2  1755.00  8315.0   49.92
# 3     202.0    13.7  ...    12.0   192.6   232.9  1591.75  1601.0   11.91
# 4     800.0  1230.0  ...    11.0  2871.3  3662.6  9132.66  9260.0  171.13
# ..      ...     ...  ...     ...     ...     ...      ...     ...     ...
# 367   350.0   108.0  ...    15.0  1408.4  1473.5  8842.18  8864.0  105.52
# 368   150.0    36.0  ...    14.0   886.4   909.2  7930.66  8004.0   73.57
# 369   430.0   285.0  ...    15.0  1821.6  1963.7  9114.22  9131.0  116.56
# 370   160.0    30.6  ...    15.0  1082.5  1176.5  8343.60  8382.0   87.27
# 371   230.0    35.6  ...    15.0   746.8   815.5  1755.00  8013.0   62.78
#
#      V-26.0    V-27.0    V-28.0     V-29.0
# 0     65.65   4294.06  10927.50   648845.6
# 1    108.51  12423.86  11774.00  1181572.6
# 2     40.26   1718.90  10058.50   540680.6
# 3     10.41    363.13  16871.50   146872.1
# 4    178.30  11568.00  12732.00  2435004.3
# ..      ...       ...       ...        ...
# 367  105.32  12113.01  45966.00  1188995.8
# 368   69.26   4756.68  21855.00   669640.3
# 369  119.13   9459.40  47096.00  1391757.1
# 370   85.56  10555.47  33626.25   865878.9
# 371   56.45   3387.72  10646.75   606524.2
#
# [372 rows x 129 columns]

# %% [markdown]
# **Reviewing the most recent starting year data (2009)**

# %%
df_lag012345[ df_lag012345['START YEAR AD'] == 2009 ]
# Out:
#      Actual Sales Price  Actual Construction Cost  START YEAR AD  \
# 7                  4600                       600           2009
# 61                 3750                       650           2009
# 62                 4000                       700           2009
# 86                 1700                       650           2009
# 97                 1900                       390           2009
# 342                2000                       450           2009
#
#      START QUARTER  COMPLETION YEAR AD  COMPLETION QUARTER  V-1     V-2  \
# 7                1                2010                   3    1  1150.0
# 61               1                2010                   3    3  1500.0
# 62               2                2011                   1    3  3100.0
# 86               1                2010                   4    4  1800.0
# 97               4                2010                   4    4  1450.0
# 342              3                2011                   1   20  1560.0
#
#        V-3     V-4  ...  V-20.0   V-21.0   V-22.0   V-23.0  V-24.0  V-25.0  \
# 7    380.0   575.0  ...    11.0  3746.01  4215.95  9833.67  9908.0  196.76
# 61   350.0   810.0  ...    11.0  3746.01  4215.95  9833.67  9908.0  196.76
# 62   640.0  1798.0  ...    11.0  3962.24  4472.30  9925.49  9988.0  201.66
# 86   500.0   954.0  ...    11.0  3746.01  4215.95  9833.67  9908.0  196.76
# 97   336.0   536.5  ...     NaN      NaN      NaN      NaN     NaN     NaN
# 342  520.0   624.0  ...    11.0  4188.65  4741.56  9916.90  9963.0  204.70
#
#      V-26.0   V-27.0    V-28.0     V-29.0
# 7     215.0   9258.4  12910.71  2183435.0
# 61    215.0   9258.4  12910.71  2183435.0
# 62    218.4  11479.8  25821.42  2271543.7
# 86    215.0   9258.4  12910.71  2183435.0
# 97      NaN      NaN       NaN        NaN
# 342   222.6  11274.9  38732.14  2606321.0
#
# [6 rows x 129 columns]

# %% [markdown]
# **Finding & Precaution: Data in the latest starting month (2009Q4) with have missing values**

# %% [markdown]
# ## Output new dataframe: Original DF with Lag-0 data only

# %% [markdown]
# **df_onLag0**

# %%
#check all column headers
pd.set_option('display.max_columns', 70) #expand limit on display lengthy table
print(df_lag012345.iloc[0:0,:70])
print(df_lag012345.iloc[0:0,70:])
pd.set_option('display.max_columns', 20) #set it back to default (20)
# Out:
# Empty DataFrame
# Columns: [Actual Sales Price, Actual Construction Cost, START YEAR AD, START QUARTER, COMPLETION YEAR AD, COMPLETION QUARTER, V-1, V-2, V-3, V-4, V-5, V-6, V-7, V-8, V-11, V-12, V-13, V-14, V-15, V-16, V-17, V-18, V-19, V-20, V-21, V-22, V-23, V-24, V-25, V-26, V-27, V-28, V-29, V-11.1, V-12.1, V-13.1, V-14.1, V-15.1, V-16.1, V-17.1, V-18.1, V-19.1, V-20.1, V-21.1, V-22.1, V-23.1, V-24.1, V-25.1, V-26.1, V-27.1, V-28.1, V-29.1, V-11.2, V-12.2, V-13.2, V-14.2, V-15.2, V-16.2, V-17.2, V-18.2, V-19.2, V-20.2, V-21.2, V-22.2, V-23.2, V-24.2, V-25.2, V-26.2, V-27.2, V-28.2]
# Index: []
# Empty DataFrame
# Columns: [V-29.2, V-11.3, V-12.3, V-13.3, V-14.3, V-15.3, V-16.3, V-17.3, V-18.3, V-19.3, V-20.3, V-21.3, V-22.3, V-23.3, V-24.3, V-25.3, V-26.3, V-27.3, V-28.3, V-29.3, V-11.4, V-12.4, V-13.4, V-14.4, V-15.4, V-16.4, V-17.4, V-18.4, V-19.4, V-20.4, V-21.4, V-22.4, V-23.4, V-24.4, V-25.4, V-26.4, V-27.4, V-28.4, V-29.4, START YEAR AND QUARTER, V-11.0, V-12.0, V-13.0, V-14.0, V-15.0, V-16.0, V-17.0, V-18.0, V-19.0, V-20.0, V-21.0, V-22.0, V-23.0, V-24.0, V-25.0, V-26.0, V-27.0, V-28.0, V-29.0]
# Index: []

# %%
df_onLag0 = pd.concat([df_lag012345.loc[:,'Actual Sales Price':'V-8'],df_lag012345.loc[:,'START YEAR AND QUARTER':'V-29.0']],axis=1)
df_onLag0
# Out:
#      Actual Sales Price  Actual Construction Cost  START YEAR AD  \
# 0                  2200                       410           2002
# 1                  5000                      1000           2005
# 2                  1200                       170           1999
# 3                   165                        30           1993
# 4                  5500                       700           2008
# ..                  ...                       ...            ...
# 367                1100                       150           2004
# 368                 740                        80           2002
# 369                 860                       220           2005
# 370                1100                       110           2003
# 371                 460                        50           2001
#
#      START QUARTER  COMPLETION YEAR AD  COMPLETION QUARTER  V-1     V-2  \
# 0                1                2006                   1    1  3150.0
# 1                1                2010                   4    1  7600.0
# 2                1                2002                   4    1  4800.0
# 3                2                1994                   2    1   685.0
# 4                1                2011                   2    1  3000.0
# ..             ...                 ...                 ...  ...     ...
# 367              4                2007                   1   20  1350.0
# 368              2                2003                   4   20   600.0
# 369              4                2007                   3   20  1900.0
# 370              3                2005                   4   20   510.0
# 371              1                2002                   3   20   890.0
#
#         V-3     V-4  ...  V-20.0  V-21.0  V-22.0   V-23.0  V-24.0  V-25.0  \
# 0     920.0   598.5  ...    14.0   831.8   938.4  7924.48  7994.0   71.56
# 1    1140.0  3040.0  ...    15.0  1836.6  1932.5  8920.04  8938.0  110.51
# 2     840.0   480.0  ...    15.0   641.5   652.2  1755.00  8315.0   49.92
# 3     202.0    13.7  ...    12.0   192.6   232.9  1591.75  1601.0   11.91
# 4     800.0  1230.0  ...    11.0  2871.3  3662.6  9132.66  9260.0  171.13
# ..      ...     ...  ...     ...     ...     ...      ...     ...     ...
# 367   350.0   108.0  ...    15.0  1408.4  1473.5  8842.18  8864.0  105.52
# 368   150.0    36.0  ...    14.0   886.4   909.2  7930.66  8004.0   73.57
# 369   430.0   285.0  ...    15.0  1821.6  1963.7  9114.22  9131.0  116.56
# 370   160.0    30.6  ...    15.0  1082.5  1176.5  8343.60  8382.0   87.27
# 371   230.0    35.6  ...    15.0   746.8   815.5  1755.00  8013.0   62.78
#
#      V-26.0    V-27.0    V-28.0     V-29.0
# 0     65.65   4294.06  10927.50   648845.6
# 1    108.51  12423.86  11774.00  1181572.6
# 2     40.26   1718.90  10058.50   540680.6
# 3     10.41    363.13  16871.50   146872.1
# 4    178.30  11568.00  12732.00  2435004.3
# ..      ...       ...       ...        ...
# 367  105.32  12113.01  45966.00  1188995.8
# 368   69.26   4756.68  21855.00   669640.3
# 369  119.13   9459.40  47096.00  1391757.1
# 370   85.56  10555.47  33626.25   865878.9
# 371   56.45   3387.72  10646.75   606524.2
#
# [372 rows x 34 columns]

# %%
df_onLag0.to_pickle('df_onLag0.pkl')
df_onLag0.to_csv('df_onLag0.csv')

# %% [markdown]
# ## Output new dataframe: Original DF with Moving-Average on FOUR Lag-1,2,3,4 data

# %% [markdown]
# **df_mAvgFour**

# %%
#check column indeces to be extract for averaging
print(df.iloc[0:0,[14,32]]) #lag1 data running from col14 to col32 (inclusive)
print(df.iloc[0:0,[33,51]]) #lag2 data: col33 to col51 (inclusive)
print(df.iloc[0:0,[52,70]]) #lag3 data: col52 to col70 (inclusive)
print(df.iloc[0:0,[71,89]]) #lag4 data: col71 to col89 (inclusive)
# Out:
# Empty DataFrame
# Columns: [V-11, V-29]
# Index: []
# Empty DataFrame
# Columns: [V-11.1, V-29.1]
# Index: []
# Empty DataFrame
# Columns: [V-11.2, V-29.2]
# Index: []
# Empty DataFrame
# Columns: [V-11.3, V-29.3]
# Index: []

# %%
def gen_new_df(df, first_col_lag1=14, last_col_lag1=32, lags_taken=4):
  '''
  From a full dataframes carrying multiple lag data,
  generate a new dataframe of moving-average of multiple lag-data

  Input
  =====
  df (dataframe): Full dataframes with multiple lags
  first_col_lag1 (int): First column in the first lag
  last_col_lag1 (int): Last column in the first lag
  lags_taken (int): How many lags to be taken

  Output
  ======
  new_df (dataframe): A dataframe summarise multiple lags in fewer columns
  '''

  import numpy as np

  mAvg_df = pd.DataFrame()
  lg = str(lags_taken)
  cols_per_lag = last_col_lag1 - first_col_lag1 + 1

  for col_index in np.arange(first_col_lag1, last_col_lag1 + 1): #e.g. for np.arange is an array([14,15,16, ..., 32])
    for x in np.arange(lags_taken):
      if x == 0:
        mAvg_df[df.columns[col_index]+'.mA'+lg+'l'] = df.iloc[:,col_index]
      else:
        mAvg_df[df.columns[col_index]+'.mA'+lg+'l'] = mAvg_df[df.columns[col_index]+'.mA'+lg+'l'] + df.iloc[:,col_index + x*cols_per_lag]
  mAvg_df = mAvg_df/lags_taken

  result_df = pd.concat([df.iloc[:,:first_col_lag1], mAvg_df], axis=1)

  return result_df

# %%
df_mAvgFour = gen_new_df(df,14,32,4)
df_mAvgFour
# Out:
#      Actual Sales Price  Actual Construction Cost  START YEAR AD  \
# 0                  2200                       410           2002
# 1                  5000                      1000           2005
# 2                  1200                       170           1999
# 3                   165                        30           1993
# 4                  5500                       700           2008
# ..                  ...                       ...            ...
# 367                1100                       150           2004
# 368                 740                        80           2002
# 369                 860                       220           2005
# 370                1100                       110           2003
# 371                 460                        50           2001
#
#      START QUARTER  COMPLETION YEAR AD  COMPLETION QUARTER  V-1     V-2  \
# 0                1                2006                   1    1  3150.0
# 1                1                2010                   4    1  7600.0
# 2                1                2002                   4    1  4800.0
# 3                2                1994                   2    1   685.0
# 4                1                2011                   2    1  3000.0
# ..             ...                 ...                 ...  ...     ...
# 367              4                2007                   1   20  1350.0
# 368              2                2003                   4   20   600.0
# 369              4                2007                   3   20  1900.0
# 370              3                2005                   4   20   510.0
# 371              1                2002                   3   20   890.0
#
#         V-3     V-4  ...  V-20.mA4l    V-21.mA4l  V-22.mA4l  V-23.mA4l  \
# 0     920.0   598.5  ...      15.00   774.225000   826.4000   1755.000
# 1    1140.0  3040.0  ...      15.00  1356.375000  1433.8500   8718.540
# 2     840.0   480.0  ...      15.00   579.102124   658.2400   1755.000
# 3     202.0    13.7  ...      12.00   174.242877   196.9375   1501.695
# 4     800.0  1230.0  ...      11.00  2517.400000  2825.4750   9282.345
# ..      ...     ...  ...        ...          ...        ...        ...
# 367   350.0   108.0  ...      15.00  1290.225000  1394.5500   8599.190
# 368   150.0    36.0  ...      14.75   795.475000   857.1250   3297.370
# 369   430.0   285.0  ...      15.00  1634.325000  1754.7250   8956.685
# 370   160.0    30.6  ...      14.50   989.875000  1145.7750   8099.720
# 371   230.0    35.6  ...      15.00   723.000000   772.6500   1755.000
#
#      V-24.mA4l  V-25.mA4l  V-26.mA4l   V-27.mA4l   V-28.mA4l    V-29.mA4l
# 0      8008.75    64.8200    59.6950   3508.2300  26616.8750   608637.350
# 1      8745.75    99.9975   100.0000  12836.1700  28728.7500  1046230.025
# 2      6469.75    43.0325    35.7300   1550.6150  24416.2500   451132.475
# 3      1547.00    10.6400     9.5125    481.8350  20545.4375   129030.050
# 4      9357.25   146.2125   153.3750   9805.5000  30982.5000  1910539.875
# ..         ...        ...        ...         ...         ...          ...
# 367    8628.00    96.3550    96.1175  12652.7600  28446.0000   981237.850
# 368    8004.00    67.0150    61.9950   3734.8150  26687.0625   619217.700
# 369    8975.50   109.3000   110.3825  11313.1300  29152.5000  1180030.500
# 370    8147.25    80.9975    78.3800   6463.9475  27529.6875   782909.950
# 371    8188.25    58.1900    50.2425   2702.4475  25879.3750   605664.400
#
# [372 rows x 33 columns]

# %%
#df_mAvgFour.to_csv(path + 'df_mAvgFour_for_gen_new_df.csv') #offline check

# %%
df_mAvgFour.to_pickle('df_mAvgFour.pkl')
df_mAvgFour.to_csv('df_mAvgFour.csv')

# %% [markdown]
# ## Output new dataframe: Original DF with Moving-Average on FIVE Lag-1,2,3,4,5

# %%
df_mAvgFive = gen_new_df(df,14,32,5)
df_mAvgFive
# Out:
#      Actual Sales Price  Actual Construction Cost  START YEAR AD  \
# 0                  2200                       410           2002
# 1                  5000                      1000           2005
# 2                  1200                       170           1999
# 3                   165                        30           1993
# 4                  5500                       700           2008
# ..                  ...                       ...            ...
# 367                1100                       150           2004
# 368                 740                        80           2002
# 369                 860                       220           2005
# 370                1100                       110           2003
# 371                 460                        50           2001
#
#      START QUARTER  COMPLETION YEAR AD  COMPLETION QUARTER  V-1     V-2  \
# 0                1                2006                   1    1  3150.0
# 1                1                2010                   4    1  7600.0
# 2                1                2002                   4    1  4800.0
# 3                2                1994                   2    1   685.0
# 4                1                2011                   2    1  3000.0
# ..             ...                 ...                 ...  ...     ...
# 367              4                2007                   1   20  1350.0
# 368              2                2003                   4   20   600.0
# 369              4                2007                   3   20  1900.0
# 370              3                2005                   4   20   510.0
# 371              1                2002                   3   20   890.0
#
#         V-3     V-4  ...  V-20.mA5l    V-21.mA5l  V-22.mA5l  V-23.mA5l  \
# 0     920.0   598.5  ...       15.0   766.140000    824.220   1755.000
# 1    1140.0  3040.0  ...       15.0  1313.860000   1410.340   8647.788
# 2     840.0   480.0  ...       15.0   581.181700    679.752   1755.000
# 3     202.0    13.7  ...       12.0   178.930213    188.000   1489.818
# 4     800.0  1230.0  ...       11.6  2458.040000   2709.200   9272.228
# ..      ...     ...  ...        ...          ...        ...        ...
# 367   350.0   108.0  ...       15.0  1248.680000   1350.940   8548.072
# 368   150.0    36.0  ...       14.8   785.740000    848.800   2988.896
# 369   430.0   285.0  ...       15.0  1592.280000   1720.640   8920.690
# 370   160.0    30.6  ...       14.4   969.180000   1098.460   8065.908
# 371   230.0    35.6  ...       15.0   704.380000    771.020   1755.000
#
#      V-24.mA5l  V-25.mA5l  V-26.mA5l  V-27.mA5l  V-28.mA5l   V-29.mA5l
# 0       8007.4     64.004     58.608   3402.236   29574.90   607307.50
# 1       8675.2     98.188     97.958  12544.810   31950.00  1022789.44
# 2       6161.8     42.166     34.992   1571.104   27119.60   436471.70
# 3       1528.8     10.458      9.278    522.700   18075.15   127630.38
# 4       9343.0    144.290    150.740   9808.600   34438.00  1875426.60
# ..         ...        ...        ...        ...        ...         ...
# 367     8578.8     94.538     94.006  12233.302   29482.05   958166.06
# 368     8005.8     66.168     60.886   3665.396   23479.00   616679.00
# 369     8940.2    107.640    108.684  11764.864   30216.90  1157578.80
# 370     8118.6     79.512     76.556   6122.494   26394.75   760256.02
# 371     8234.6     57.476     49.152   2603.196   28750.30   610490.96
#
# [372 rows x 33 columns]

# %%
df_mAvgFive.to_pickle('df_mAvgFive.pkl')
df_mAvgFive.to_csv('df_mAvgFive.csv')

# %%
df_mAvgFour = pd.read_pickle("df_mAvgFour.pkl")

# %%
df_mAvgFour = df_mAvgFour.rename(columns={'Actual Sales Price':'Unit Sales Price','Actual Construction Cost':'Unit Construction Cost'})
df_mAvgFour['Unit Sales Price'] = df_mAvgFour['Unit Sales Price'].div(df_mAvgFour['V-2'])*10000
df_mAvgFour['Unit Construction Cost'] = df_mAvgFour['Unit Construction Cost'].div(df_mAvgFour['V-2'])*10000
df_mAvgFour
# Out:
#      Unit Sales Price  Unit Construction Cost  START YEAR AD  START QUARTER  \
# 0         6984.126984             1301.587302           2002              1
# 1         6578.947368             1315.789474           2005              1
# 2         2500.000000              354.166667           1999              1
# 3         2408.759124              437.956204           1993              2
# 4        18333.333333             2333.333333           2008              1
# ..                ...                     ...            ...            ...
# 367       8148.148148             1111.111111           2004              4
# 368      12333.333333             1333.333333           2002              2
# 369       4526.315789             1157.894737           2005              4
# 370      21568.627451             2156.862745           2003              3
# 371       5168.539326              561.797753           2001              1
#
#      COMPLETION YEAR AD  COMPLETION QUARTER  V-1     V-2     V-3     V-4  ...  \
# 0                  2006                   1    1  3150.0   920.0   598.5  ...
# 1                  2010                   4    1  7600.0  1140.0  3040.0  ...
# 2                  2002                   4    1  4800.0   840.0   480.0  ...
# 3                  1994                   2    1   685.0   202.0    13.7  ...
# 4                  2011                   2    1  3000.0   800.0  1230.0  ...
# ..                  ...                 ...  ...     ...     ...     ...  ...
# 367                2007                   1   20  1350.0   350.0   108.0  ...
# 368                2003                   4   20   600.0   150.0    36.0  ...
# 369                2007                   3   20  1900.0   430.0   285.0  ...
# 370                2005                   4   20   510.0   160.0    30.6  ...
# 371                2002                   3   20   890.0   230.0    35.6  ...
#
#      V-20.mA4l    V-21.mA4l  V-22.mA4l  V-23.mA4l  V-24.mA4l  V-25.mA4l  \
# 0        15.00   774.225000   826.4000   1755.000    8008.75    64.8200
# 1        15.00  1356.375000  1433.8500   8718.540    8745.75    99.9975
# 2        15.00   579.102124   658.2400   1755.000    6469.75    43.0325
# 3        12.00   174.242877   196.9375   1501.695    1547.00    10.6400
# 4        11.00  2517.400000  2825.4750   9282.345    9357.25   146.2125
# ..         ...          ...        ...        ...        ...        ...
# 367      15.00  1290.225000  1394.5500   8599.190    8628.00    96.3550
# 368      14.75   795.475000   857.1250   3297.370    8004.00    67.0150
# 369      15.00  1634.325000  1754.7250   8956.685    8975.50   109.3000
# 370      14.50   989.875000  1145.7750   8099.720    8147.25    80.9975
# 371      15.00   723.000000   772.6500   1755.000    8188.25    58.1900
#
#      V-26.mA4l   V-27.mA4l   V-28.mA4l    V-29.mA4l
# 0      59.6950   3508.2300  26616.8750   608637.350
# 1     100.0000  12836.1700  28728.7500  1046230.025
# 2      35.7300   1550.6150  24416.2500   451132.475
# 3       9.5125    481.8350  20545.4375   129030.050
# 4     153.3750   9805.5000  30982.5000  1910539.875
# ..         ...         ...         ...          ...
# 367    96.1175  12652.7600  28446.0000   981237.850
# 368    61.9950   3734.8150  26687.0625   619217.700
# 369   110.3825  11313.1300  29152.5000  1180030.500
# 370    78.3800   6463.9475  27529.6875   782909.950
# 371    50.2425   2702.4475  25879.3750   605664.400
#
# [372 rows x 33 columns]

# %%
df_mAvgFourNew = df_mAvgFour.copy()

for i in np.arange(11,30):
  df_mAvgFourNew['V-2_V-'+str(i)+'.mA4l']=df_mAvgFour['V-2']*df_mAvgFourNew['V-'+str(i)+'.mA4l']
for i in np.arange(11,30):
  df_mAvgFourNew['V-3_V-'+str(i)+'.mA4l']=df_mAvgFour['V-3']*df_mAvgFourNew['V-'+str(i)+'.mA4l']

for i in np.arange(11,30):
  df_mAvgFourNew = df_mAvgFourNew.drop(columns=['V-'+str(i)+'.mA4l'])

df_mAvgFourNew=df_mAvgFourNew.rename(columns={'Unit Sales Price':'Sales Price'})
df_mAvgFourNew['Sales Price'] = df_mAvgFourNew['Sales Price']*df_mAvgFourNew['V-2']/10000

df_mAvgFourNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sales Price             372 non-null    float64
#  1   Unit Construction Cost  372 non-null    float64
#  2   START YEAR AD           372 non-null    int64
#  3   START QUARTER           372 non-null    int64
#  4   COMPLETION YEAR AD      372 non-null    int64
#  5   COMPLETION QUARTER      372 non-null    int64
#  6   V-1                     372 non-null    int64
#  7   V-2                     372 non-null    float64
#  8   V-3                     372 non-null    float64
#  9   V-4                     372 non-null    float64
#  10  V-5                     372 non-null    int64
#  11  V-6                     372 non-null    float64
#  12  V-7                     372 non-null    int64
#  13  V-8                     372 non-null    int64
#  14  V-2_V-11.mA4l           372 non-null    float64
#  15  V-2_V-12.mA4l           372 non-null    float64
#  16  V-2_V-13.mA4l           372 non-null    float64
#  17  V-2_V-14.mA4l           372 non-null    float64
#  18  V-2_V-15.mA4l           372 non-null    float64
#  19  V-2_V-16.mA4l           372 non-null    float64
#  20  V-2_V-17.mA4l           372 non-null    float64
#  21  V-2_V-18.mA4l           372 non-null    float64
#  22  V-2_V-19.mA4l           372 non-null    float64
#  23  V-2_V-20.mA4l           372 non-null    float64
#  24  V-2_V-21.mA4l           372 non-null    float64
#  25  V-2_V-22.mA4l           372 non-null    float64
#  26  V-2_V-23.mA4l           372 non-null    float64
#  27  V-2_V-24.mA4l           372 non-null    float64
#  28  V-2_V-25.mA4l           372 non-null    float64
#  29  V-2_V-26.mA4l           372 non-null    float64
#  30  V-2_V-27.mA4l           372 non-null    float64
#  31  V-2_V-28.mA4l           372 non-null    float64
#  32  V-2_V-29.mA4l           372 non-null    float64
#  33  V-3_V-11.mA4l           372 non-null    float64
#  34  V-3_V-12.mA4l           372 non-null    float64
#  35  V-3_V-13.mA4l           372 non-null    float64
#  36  V-3_V-14.mA4l           372 non-null    float64
#  37  V-3_V-15.mA4l           372 non-null    float64
#  38  V-3_V-16.mA4l           372 non-null    float64
#  39  V-3_V-17.mA4l           372 non-null    float64
#  40  V-3_V-18.mA4l           372 non-null    float64
#  41  V-3_V-19.mA4l           372 non-null    float64
#  42  V-3_V-20.mA4l           372 non-null    float64
#  43  V-3_V-21.mA4l           372 non-null    float64
#  44  V-3_V-22.mA4l           372 non-null    float64
#  45  V-3_V-23.mA4l           372 non-null    float64
#  46  V-3_V-24.mA4l           372 non-null    float64
#  47  V-3_V-25.mA4l           372 non-null    float64
#  48  V-3_V-26.mA4l           372 non-null    float64
#  49  V-3_V-27.mA4l           372 non-null    float64
#  50  V-3_V-28.mA4l           372 non-null    float64
#  51  V-3_V-29.mA4l           372 non-null    float64
# dtypes: float64(44), int64(8)
# memory usage: 151.2 KB

# %%
df_mAvgFourNew_v2 = df_mAvgFourNew.copy()
df_mAvgFourNew_v2['V-2_V-20.mA4l'] = df_mAvgFourNew['V-7']*df_mAvgFourNew['V-2_V-20.mA4l'] # duration interact with interest
df_mAvgFourNew_v2['V-2_V-20.mA4l']
# Out:
# 0       756000.0
# 1      2622000.0
# 2      1080000.0
# 3        32880.0
# 4       429000.0
#          ...
# 367     182250.0
# 368      53100.0
# 369     199500.0
# 370      66555.0
# 371      80100.0
# Name: V-2_V-20.mA4l, Length: 372, dtype: float64

# %%
df_mAvgFourNew_v2['V-3_V-20.mA4l'] = df_mAvgFourNew['V-7']*df_mAvgFourNew['V-3_V-20.mA4l'] # duration interact with interest
df_mAvgFourNew_v2['V-3_V-20.mA4l']
# Out:
# 0      220800.0
# 1      393300.0
# 2      189000.0
# 3        9696.0
# 4      114400.0
#          ...
# 367     47250.0
# 368     13275.0
# 369     45150.0
# 370     20880.0
# 371     20700.0
# Name: V-3_V-20.mA4l, Length: 372, dtype: float64

# %%
df_mAvgFourNew_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sales Price             372 non-null    float64
#  1   Unit Construction Cost  372 non-null    float64
#  2   START YEAR AD           372 non-null    int64
#  3   START QUARTER           372 non-null    int64
#  4   COMPLETION YEAR AD      372 non-null    int64
#  5   COMPLETION QUARTER      372 non-null    int64
#  6   V-1                     372 non-null    int64
#  7   V-2                     372 non-null    float64
#  8   V-3                     372 non-null    float64
#  9   V-4                     372 non-null    float64
#  10  V-5                     372 non-null    int64
#  11  V-6                     372 non-null    float64
#  12  V-7                     372 non-null    int64
#  13  V-8                     372 non-null    int64
#  14  V-2_V-11.mA4l           372 non-null    float64
#  15  V-2_V-12.mA4l           372 non-null    float64
#  16  V-2_V-13.mA4l           372 non-null    float64
#  17  V-2_V-14.mA4l           372 non-null    float64
#  18  V-2_V-15.mA4l           372 non-null    float64
#  19  V-2_V-16.mA4l           372 non-null    float64
#  20  V-2_V-17.mA4l           372 non-null    float64
#  21  V-2_V-18.mA4l           372 non-null    float64
#  22  V-2_V-19.mA4l           372 non-null    float64
#  23  V-2_V-20.mA4l           372 non-null    float64
#  24  V-2_V-21.mA4l           372 non-null    float64
#  25  V-2_V-22.mA4l           372 non-null    float64
#  26  V-2_V-23.mA4l           372 non-null    float64
#  27  V-2_V-24.mA4l           372 non-null    float64
#  28  V-2_V-25.mA4l           372 non-null    float64
#  29  V-2_V-26.mA4l           372 non-null    float64
#  30  V-2_V-27.mA4l           372 non-null    float64
#  31  V-2_V-28.mA4l           372 non-null    float64
#  32  V-2_V-29.mA4l           372 non-null    float64
#  33  V-3_V-11.mA4l           372 non-null    float64
#  34  V-3_V-12.mA4l           372 non-null    float64
#  35  V-3_V-13.mA4l           372 non-null    float64
#  36  V-3_V-14.mA4l           372 non-null    float64
#  37  V-3_V-15.mA4l           372 non-null    float64
#  38  V-3_V-16.mA4l           372 non-null    float64
#  39  V-3_V-17.mA4l           372 non-null    float64
#  40  V-3_V-18.mA4l           372 non-null    float64
#  41  V-3_V-19.mA4l           372 non-null    float64
#  42  V-3_V-20.mA4l           372 non-null    float64
#  43  V-3_V-21.mA4l           372 non-null    float64
#  44  V-3_V-22.mA4l           372 non-null    float64
#  45  V-3_V-23.mA4l           372 non-null    float64
#  46  V-3_V-24.mA4l           372 non-null    float64
#  47  V-3_V-25.mA4l           372 non-null    float64
#  48  V-3_V-26.mA4l           372 non-null    float64
#  49  V-3_V-27.mA4l           372 non-null    float64
#  50  V-3_V-28.mA4l           372 non-null    float64
#  51  V-3_V-29.mA4l           372 non-null    float64
# dtypes: float64(44), int64(8)
# memory usage: 151.2 KB

# %%
cov_matrix = df_mAvgFour.cov()
print("Covariance matrix:")
print(cov_matrix)
# Out:
# Covariance matrix:
#                         Unit Sales Price  Unit Construction Cost  \
# Unit Sales Price            1.529250e+08            2.245149e+07
# Unit Construction Cost      2.245149e+07            4.634955e+06
# START YEAR AD               2.246559e+04            4.215223e+03
# START QUARTER              -7.098206e+00           -7.870667e+01
# COMPLETION YEAR AD          2.320492e+04            4.351426e+03
# COMPLETION QUARTER          9.002437e+01            1.165574e+02
# V-1                        -6.098757e+03            1.134666e+03
# V-2                        -7.030085e+06           -1.448913e+06
# V-3                        -1.712091e+06           -3.471056e+05
# V-4                        -6.361554e+05           -1.602490e+05
# V-5                         5.339801e+05            9.448912e+04
# V-6                        -1.740298e+05           -3.686558e+04
# V-7                         3.054462e+03            7.400743e+02
# V-8                         5.410902e+06            4.664480e+05
# V-11.mA4l                   4.681896e+06            6.874517e+05
# V-12.mA4l                   2.914482e+05            5.698082e+04
# V-13.mA4l                   2.415463e+05            4.667676e+04
# V-14.mA4l                   4.420889e+03            7.047506e+02
# V-15.mA4l                   2.578542e+09            4.999731e+08
# V-16.mA4l                   1.636842e+07            3.184657e+06
# V-17.mA4l                   3.092419e+05            6.127575e+04
# V-18.mA4l                   3.078340e+05            5.494600e+04
# V-19.mA4l                   8.690782e+07            1.620482e+07
# V-20.mA4l                  -4.316295e+03           -8.903271e+02
# V-21.mA4l                   4.105908e+06            7.957298e+05
# V-22.mA4l                   4.287449e+06            8.416226e+05
# V-23.mA4l                   1.716066e+07            3.452678e+06
# V-24.mA4l                   9.553006e+06            1.677852e+06
# V-25.mA4l                   2.312478e+05            4.436424e+04
# V-26.mA4l                   2.579465e+05            4.980995e+04
# V-27.mA4l                   1.927712e+07            3.900591e+06
# V-28.mA4l                   1.606860e+07            3.013102e+06
# V-29.mA4l                   2.956407e+09            5.753138e+08
#
#                         START YEAR AD  START QUARTER  COMPLETION YEAR AD  \
# Unit Sales Price         2.246559e+04      -7.098206        2.320492e+04
# Unit Construction Cost   4.215223e+03     -78.706670        4.351426e+03
# START YEAR AD            1.749031e+01      -0.553517        1.746013e+01
# START QUARTER           -5.535171e-01       1.173717       -2.629771e-01
# COMPLETION YEAR AD       1.746013e+01      -0.262977        1.784132e+01
# V-22.mA4l               2.783895e+06  2.299771e+06  4.798262e+08
# V-23.mA4l               1.404566e+07  9.351672e+06  1.668141e+09
# V-24.mA4l               6.388951e+06  5.544508e+06  8.498228e+08
# V-25.mA4l               1.560833e+05  1.248541e+05  2.392869e+07
# V-26.mA4l               1.748492e+05  1.388968e+05  2.693068e+07
# V-27.mA4l               1.805399e+07  1.111698e+07  1.884790e+09
# V-28.mA4l               1.111698e+07  8.832179e+06  1.550229e+09
# V-29.mA4l               1.884790e+09  1.550229e+09  3.238595e+11
#
# [33 rows x 33 columns]

# %%
cor_matrix = df_mAvgFour.corr()
print("Correlation matrix:")
print(cor_matrix)
# Out:
# Correlation matrix:
#                         Unit Sales Price  Unit Construction Cost  \
# Unit Sales Price                1.000000                0.843302
# Unit Construction Cost          0.843302                1.000000
# START YEAR AD                   0.434390                0.468165
# START QUARTER                  -0.000530               -0.033745
# COMPLETION YEAR AD              0.444250                0.478515
# COMPLETION QUARTER              0.006480                0.048191
# V-1                            -0.075141                0.080301
# V-2                            -0.315411               -0.373401
# V-3                            -0.282503               -0.328984
# V-4                            -0.091284               -0.132082
# V-5                             0.383469                0.389766
# V-6                            -0.051155               -0.062244
# V-7                             0.117815                0.163968
# V-8                             0.439387                0.217569
# V-11.mA4l                       0.254420                0.214580
# V-12.mA4l                       0.413224                0.464054
# V-13.mA4l                       0.427230                0.474218
# V-14.mA4l                       0.263081                0.240897
# V-15.mA4l                       0.421061                0.468958
# V-16.mA4l                       0.386131                0.431526
# V-17.mA4l                       0.393178                0.447503
# V-18.mA4l                       0.410381                0.420750
# V-19.mA4l                       0.433089                0.463851
# V-20.mA4l                      -0.262800               -0.311372
# V-21.mA4l                       0.420185                0.467749
# V-22.mA4l                       0.405306                0.457002
# V-23.mA4l                       0.395871                0.457501
# V-24.mA4l                       0.374600                0.377918
# V-25.mA4l                       0.434066                0.478330
# V-26.mA4l                       0.431505                0.478618
# V-27.mA4l                       0.366874                0.426404
# V-28.mA4l                       0.437225                0.470931
# V-29.mA4l                       0.420094                0.469574
#
#                         START YEAR AD  START QUARTER  COMPLETION YEAR AD  \
# Unit Sales Price             0.434390      -0.000530            0.444250
# Unit Construction Cost       0.468165      -0.033745            0.478515
# START YEAR AD                1.000000      -0.122166            0.988406
# START QUARTER               -0.122166       1.000000           -0.057468
# COMPLETION YEAR AD           0.988406      -0.057468            1.000000
# COMPLETION QUARTER           0.053076      -0.198444           -0.020705
# V-1                          0.135501       0.034600            0.136519
# V-2                          0.089259      -0.021322            0.100534
# V-3                          0.066719      -0.007892            0.069694
# V-4                          0.336241      -0.045533            0.349245
# V-5                          0.766044      -0.107190            0.761857
# V-6                         -0.148846      -0.116201           -0.139225
# V-7                          0.077807      -0.111428            0.190784
# V-8                          0.610478      -0.085711            0.608805
# V-11.mA4l                    0.453333      -0.045799            0.444873
# V-12.mA4l                    0.910735      -0.039263            0.898559
# V-13.mA4l                    0.945423      -0.043838            0.933880
# V-14.mA4l                    0.512264      -0.044479            0.504142
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unit Sales Price        372 non-null    float64
#  1   Unit Construction Cost  372 non-null    float64
#  2   START YEAR AD           372 non-null    int64
#  3   START QUARTER           372 non-null    int64
#  4   COMPLETION YEAR AD      372 non-null    int64
#  5   COMPLETION QUARTER      372 non-null    int64
#  6   V-1                     372 non-null    int64
#  7   V-2                     372 non-null    float64
#  8   V-3                     372 non-null    float64
#  9   V-4                     372 non-null    float64
#  10  V-5                     372 non-null    int64
#  11  V-6                     372 non-null    float64
#  12  V-7                     372 non-null    int64
#  13  V-8                     372 non-null    int64
#  14  V-11.mA4l               372 non-null    float64
#  15  V-12.mA4l               372 non-null    float64
#  16  V-13.mA4l               372 non-null    float64
#  17  V-14.mA4l               372 non-null    float64
#  18  V-15.mA4l               372 non-null    float64
#  19  V-16.mA4l               372 non-null    float64
#  20  V-17.mA4l               372 non-null    float64
#  21  V-18.mA4l               372 non-null    float64
#  22  V-19.mA4l               372 non-null    float64
#  23  V-20.mA4l               372 non-null    float64
#  24  V-21.mA4l               372 non-null    float64
#  25  V-22.mA4l               372 non-null    float64
#  26  V-23.mA4l               372 non-null    float64
#  27  V-24.mA4l               372 non-null    float64
#  28  V-25.mA4l               372 non-null    float64
#  29  V-26.mA4l               372 non-null    float64
#  30  V-27.mA4l               372 non-null    float64
#  31  V-28.mA4l               372 non-null    float64
#  32  V-29.mA4l               372 non-null    float64
# dtypes: float64(25), int64(8)
# memory usage: 96.0 KB

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score,KFold
import statsmodels.formula.api as smf
from sklearn.preprocessing import StandardScaler

x_old_ori = df_mAvgFour.iloc[:,6:]
y_old = df_mAvgFour.iloc[:,0]
x_train_old,x_test_old,y_train_old,y_test_old = train_test_split(x_old_ori,y_old,test_size=0.3,random_state=0)
sc = StandardScaler()
x_train_old = sc.fit_transform(x_train_old)
x_test_old = sc.transform(x_test_old)

# %%
sc = StandardScaler()
x_old = sc.fit_transform(x_old_ori)

# %%
from sklearn.decomposition import PCA

scores = []

n_components_old = range(1, x_old.shape[1] + 1)


for n_old in n_components_old:
    pca_old = PCA(n_components=n_old)
    X_pca_old = pca_old.fit_transform(x_old)


    model = LinearRegression()
    score = cross_val_score(model, X_pca_old, y_old, cv=5, scoring="r2") #use all dataset to do the cross validation
    scores.append(score.mean())
    
    

# Draw RMSE plot
plt.figure(figsize=(12, 6))
plt.plot(n_components_old, scores, marker='o')
plt.title('cvscore vs. Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('cvscore of old data')
plt.grid()

plt.show()


best_components_old = n_components_old[np.argmax(scores)]
print(f'Best value of n_components : {best_components_old}')
# Out:
# Best value of n_components : 8

# %%
pca_old = PCA(n_components=8)

X_train_pca = pca_old.fit_transform(x_train_old)
X_test_pca = pca_old.transform(x_test_old)
X_pca_old = pca_old.fit_transform(x_old)

model_old = LinearRegression()
model_old.fit(X_train_pca, y_train_old)
y_pred_old = model_old.predict(X_test_pca) # use the train set and test set to get RMSE

mse = mean_squared_error(y_test_old, y_pred_old)
r2 = r2_score(y_test_old, y_pred_old)
rmse = np.sqrt(mse)
cv_scores = cross_val_score(model_old, X_pca_old, y_old, cv=5)

print(f'(MSE): {mse}')
print(f'(RMSE): {rmse}')
print(f'(R²): {r2}')
print(f'(cv_score): {cv_scores.mean()}')
# Out:
# (MSE): 147353962.3394409
# (RMSE): 12138.944037248088
# (R²): 0.40487431752907466
# (cv_score): -0.07322573884708612

# %%
x_old_ori = df_mAvgFour.iloc[:,14:] #only economic variables
y_old = df_mAvgFour.iloc[:,0]
x_train_old,x_test_old,y_train_old,y_test_old = train_test_split(x_old_ori,y_old,test_size=0.3,random_state=0)
sc = StandardScaler()
x_train_old = sc.fit_transform(x_train_old)
x_test_old = sc.transform(x_test_old)

# %%
sc = StandardScaler()
x_old = sc.fit_transform(x_old_ori)

# %%
scores = []

n_components_old = range(1, x_old.shape[1] + 1)


for n_old in n_components_old:
    pca_old = PCA(n_components=n_old)
    X_pca_old = pca_old.fit_transform(x_old)


    model = LinearRegression()
    score = cross_val_score(model, X_pca_old, y_old, cv=5) 
    scores.append(score.mean())
    
    

# Draw RMSE plot
plt.figure(figsize=(12, 6))
plt.plot(n_components_old, scores, marker='o')
plt.title('cvscore vs. Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('cvscore of old data')
plt.grid()

plt.show()


best_components_old = n_components_old[np.argmax(scores)]
print(f'Best value of n_components : {best_components_old}')
# Out:
# Best value of n_components : 3

# %%
pca_old = PCA(n_components=3)

X_train_pca = pca_old.fit_transform(x_train_old)
X_test_pca = pca_old.transform(x_test_old)
X_pca_old = pca_old.fit_transform(x_old)

model_old = LinearRegression()
model_old.fit(X_train_pca, y_train_old)
y_pred_old = model_old.predict(X_test_pca) # use the train set and test set to get RMSE


mse = mean_squared_error(y_test_old, y_pred_old)
r2 = r2_score(y_test_old, y_pred_old)
rmse = np.sqrt(mse)
cv_scores = cross_val_score(model_old, X_pca_old, y_old, cv=5)

print(f'(MSE): {mse}')
print(f'(RMSE): {rmse}')
print(f'(R²): {r2}')
print(f'(cv_score): {cv_scores.mean()}')
# Out:
# (MSE): 203266359.38646942
# (RMSE): 14257.151166571442
# (R²): 0.17905817439376526
# (cv_score): -0.33165923815682696

# %%
cov_matrix_new = df_mAvgFourNew.cov()
print("New Covariance matrix:")
print(cov_matrix_new)
# Out:
# New Covariance matrix:
#                          Sales Price  Unit Construction Cost  START YEAR AD  \
# Sales Price             1.454636e+06            5.851477e+05   3.062337e+03
# Unit Construction Cost  5.851477e+05            4.634955e+06   4.215223e+03
# START YEAR AD           3.062337e+03            4.215223e+03   1.749031e+01
# START QUARTER          -1.215572e+02           -7.870667e+01  -5.535171e-01
# COMPLETION YEAR AD      3.121142e+03            4.351426e+03   1.746013e+01
# COMPLETION QUARTER     -4.798786e+00            1.165574e+02   2.493696e-01
# V-1                    -3.444055e+03            1.134666e+03   3.719329e+00
# V-2                     5.528775e+05           -1.448913e+06   6.728168e+02
# V-3                     9.666675e+04           -3.471056e+05   1.367451e+02
# V-4                     3.486729e+05           -1.602490e+05   7.924610e+02
# V-5                     1.066091e+05            9.448912e+04   3.607512e+02
# V-6                     6.374900e+04           -3.686558e+04  -1.712523e+02
# V-7                     3.519788e+02            7.400743e+02   6.822015e-01
# V-8                     1.172742e+06            4.664480e+05   2.542449e+03
# V-2_V-11.mA4l           2.872322e+09           -4.987114e+09   7.092088e+06
# V-3_V-21.mA4l                0.997394
# V-3_V-22.mA4l                0.995959
# V-3_V-23.mA4l                0.944058
# V-3_V-24.mA4l                0.891917
# V-3_V-25.mA4l                0.993814
# V-3_V-26.mA4l                0.995940
# V-3_V-27.mA4l                0.921643
# V-3_V-28.mA4l                0.875483
# V-3_V-29.mA4l                1.000000
#
# [52 rows x 52 columns]

# %%
x_new_ori = df_mAvgFourNew.iloc[:,2:]
y_new = df_mAvgFourNew.iloc[:,0]
x_train_new,x_test_new,y_train_new,y_test_new = train_test_split(x_new_ori,y_new,test_size=0.3,random_state=100)
sc = StandardScaler()
x_train_new = sc.fit_transform(x_train_new)
x_test_new = sc.transform(x_test_new)

# %%
sc = StandardScaler()
x_new = sc.fit_transform(x_new_ori)

# %%
scores = []

n_components_new = range(1, x_train_new.shape[1] + 1)

for n_new in n_components_new:
    pca_new = PCA(n_components=n_new)
    X_pca_new = pca_new.fit_transform(x_new)

    model = LinearRegression()
    score = cross_val_score(model, X_pca_new, y_new, cv=5)
    scores.append(score.mean())
       

# Draw RMSE plot
plt.figure(figsize=(12, 6))
plt.plot(n_components_new, scores, marker='o')
plt.title('cvscore vs. Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('cvscore of new data')
plt.grid()

plt.show()


best_components_new = n_components_new[np.argmax(scores)]
print(f'Best value of n_components : {best_components_new}')
# Out:
# Best value of n_components : 9

# %%
pca_new = PCA(n_components=9)
X_train_pca_new = pca_new.fit_transform(x_train_new)
X_test_pca_new = pca_new.transform(x_test_new)

X_pca_new = pca_new.fit_transform(x_new)
model_new = LinearRegression()
model_new.fit(X_train_pca_new, y_train_new)
y_pred_new = model_new.predict(X_test_pca_new)

mse = mean_squared_error(y_test_new, y_pred_new)
r2 = r2_score(y_test_new, y_pred_new)
rmse = np.sqrt(mse)
cv_scores = cross_val_score(model_new, X_pca_new, y_new, cv=5,scoring='r2')

print(f'(MSE): {mse}')
print(f'(RMSE): {rmse}')
print(f'(R²): {r2}')
print(f'(cv_score): {cv_scores.mean()}')
# Out:
# (MSE): 224820.6222541014
# (RMSE): 474.15253057861185
# (R²): 0.8657366413315002
# (cv_score): 0.6394292472026638

# %%
x_new_ori = df_mAvgFourNew.iloc[:,14:] #only economic variables
y_new = df_mAvgFourNew.iloc[:,0]
x_train_new,x_test_new,y_train_new,y_test_new = train_test_split(x_new_ori,y_new,test_size=0.3,random_state=100)
sc = StandardScaler()
x_train_new = sc.fit_transform(x_train_new)
x_test_new = sc.transform(x_test_new)
x_new_ori
# Out:
#      V-2_V-11.mA4l  V-2_V-12.mA4l  V-2_V-13.mA4l  V-2_V-14.mA4l  \
# 0     1.906931e+07     171911.250     188488.125      16427.250
# 1     2.388300e+07     760000.000     760000.000      22059.000
# 2     9.850800e+06     190320.000     194076.000       6396.000
# 3     1.797086e+06       7826.125       5298.475       1380.275
# 4     1.958550e+07     548775.000     454485.000      17542.500
# ..             ...            ...            ...            ...
# 367   4.419900e+06     128317.500     128310.750       3952.125
# 368   3.780000e+06      33750.000      37096.500       3166.500
# 369   5.316675e+06     215602.500     199153.250       4944.750
# 370   1.457580e+06      36388.500      39267.450       1243.125
# 371   4.724565e+06      44299.750      51379.700       3824.775
#
#      V-2_V-15.mA4l  V-2_V-16.mA4l  V-2_V-17.mA4l  V-2_V-18.mA4l  \
# 0     9.146089e+08   1.089624e+07    187661.2500     471523.500
# 1     4.685164e+09   2.969453e+07    760000.0000     991800.000
# 2     7.067453e+08   5.811120e+06    162840.0000     857400.000
# 3     2.343714e+07   2.301429e+05      8355.2875      24725.075
# 4     4.466781e+09   3.013230e+07    602025.0000     737445.000
# ..             ...            ...            ...            ...
# 367   7.785365e+08   5.026455e+06    131152.5000     218700.000
# 368   1.856918e+08   2.217525e+06     38145.0000      94782.000
# 369   1.428494e+09   9.567878e+06    205057.5000     312502.500
# 370   2.155441e+08   2.410566e+06     42419.2500     115017.750
# 371   1.969447e+08   2.088140e+06     43521.0000     120706.250
#
#      V-2_V-19.mA4l  V-2_V-20.mA4l  ...  V-3_V-20.mA4l  V-3_V-21.mA4l  \
# 0     2.452393e+07        47250.0  ...        13800.0   7.122870e+05
# 1     8.352544e+07       114000.0  ...        17100.0   1.546268e+06
# 2     1.946731e+07        72000.0  ...        12600.0   4.864458e+05
# 3     2.616358e+05         8220.0  ...         2424.0   3.519706e+04
# 4     1.302090e+08        33000.0  ...         8800.0   2.013920e+06
# ..             ...            ...  ...            ...            ...
# 367   1.379196e+07        20250.0  ...         5250.0   4.515787e+05
# 368   4.794682e+06         8850.0  ...         2212.5   1.193212e+05
# 369   3.930839e+07        28500.0  ...         6450.0   7.027597e+05
# 370   4.899423e+06         7395.0  ...         2320.0   1.583800e+05
# 371   5.810365e+06        13350.0  ...         3450.0   1.662900e+05
#
#      V-3_V-22.mA4l  V-3_V-23.mA4l  V-3_V-24.mA4l  V-3_V-25.mA4l  \
# 0       760288.000     1614600.00      7368050.0       59634.40
# 1      1634589.000     9939135.60      9970155.0      113997.15
# 2       552921.600     1474200.00      5434590.0       36147.30
# 3        39781.375      303342.39       312494.0        2149.28
# 4      2260380.000     7425876.00      7485800.0      116970.00
# ..             ...            ...            ...            ...
# 367     488092.500     3009716.50      3019800.0       33724.25
# 368     128568.750      494605.50      1200600.0       10052.25
# 369     754531.750     3851374.55      3859465.0       46999.00
# 370     183324.000     1295955.20      1303560.0       12959.60
# 371     177709.500      403650.00      1883297.5       13383.70
#
#      V-3_V-26.mA4l  V-3_V-27.mA4l  V-3_V-28.mA4l  V-3_V-29.mA4l
# 0        54919.400   3.227572e+06   2.448752e+07   5.599464e+08
# 1       114000.000   1.463323e+07   3.275078e+07   1.192702e+09
# 2        30013.200   1.302517e+06   2.050965e+07   3.789513e+08
# 3         1921.525   9.733067e+04   4.150178e+06   2.606407e+07
# 4       122700.000   7.844400e+06   2.478600e+07   1.528432e+09
# ..             ...            ...            ...            ...
# 367      33641.125   4.428466e+06   9.956100e+06   3.434332e+08
# 368       9299.250   5.602222e+05   4.003059e+06   9.288266e+07
# 369      47464.475   4.864646e+06   1.253558e+07   5.074131e+08
# 370      12540.800   1.034232e+06   4.404750e+06   1.252656e+08
# 371      11555.775   6.215629e+05   5.952256e+06   1.393028e+08
#
# [372 rows x 38 columns]

# %%
sc = StandardScaler()
x_new = sc.fit_transform(x_new_ori)

# %%
scores = []

n_components_new = range(1, x_train_new.shape[1] + 1)

for n_new in n_components_new:
    pca_new = PCA(n_components=n_new)
    X_pca_new = pca_new.fit_transform(x_new)

    model = LinearRegression()
    score = cross_val_score(model, X_pca_new, y_new, cv=5)
    scores.append(score.mean())
       

# Draw RMSE plot
plt.figure(figsize=(12, 6))
plt.plot(n_components_new, scores, marker='o')
plt.title('cvscore vs. Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('cvscore of new data')
plt.grid()

plt.show()


best_components_new = n_components_new[np.argmax(scores)]
print(f'Best value of n_components : {best_components_new}')
# Out:
# Best value of n_components : 1

# %%
pca_new = PCA(n_components=1)
X_train_pca_new = pca_new.fit_transform(x_train_new)
X_test_pca_new = pca_new.transform(x_test_new)

X_pca_new = pca_new.fit_transform(x_new)
model_new = LinearRegression()
model_new.fit(X_train_pca_new, y_train_new)
y_pred_new = model_new.predict(X_test_pca_new)

mse = mean_squared_error(y_test_new, y_pred_new)
r2 = r2_score(y_test_new, y_pred_new)
rmse = np.sqrt(mse)
cv_scores = cross_val_score(model_new, X_pca_new, y_new, cv=5,scoring='r2')

print(f'(MSE): {mse}')
print(f'(RMSE): {rmse}')
print(f'(R²): {r2}')
print(f'(cv_score): {cv_scores.mean()}')
# Out:
# (MSE): 2044275.1197647133
# (RMSE): 1429.7814937131875
# (R²): -0.22084549393267605
# (cv_score): -2.4095356927517684

# %%
x_new_ori = df_mAvgFourNew_v2.iloc[:,2:]
y_new = df_mAvgFourNew_v2.iloc[:,0]
x_train_new,x_test_new,y_train_new,y_test_new = train_test_split(x_new_ori,y_new,test_size=0.3,random_state=1,shuffle=True)
sc = StandardScaler()
x_train_new = sc.fit_transform(x_train_new)
x_test_new = sc.transform(x_test_new)

# %%
sc = StandardScaler()
x_new = sc.fit_transform(x_new_ori)

# %%
scores = []

n_components_new = range(1, x_train_new.shape[1] + 1)

for n_new in n_components_new:
    pca_new = PCA(n_components=n_new)
    X_pca_new = pca_new.fit_transform(x_new)

    model = LinearRegression()
    score = cross_val_score(model, X_pca_new, y_new, cv=5)
    scores.append(score.mean())
       

# Draw RMSE plot
plt.figure(figsize=(12, 6))
plt.plot(n_components_new, scores, marker='o')
plt.title('cvscore vs. Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('cvscore of new data')
plt.grid()

plt.show()


best_components_new = n_components_new[np.argmax(scores)]
print(f'Best value of n_components : {best_components_new}')
# Out:
# Best value of n_components : 11

# %%
pca_new = PCA(n_components=11)
X_train_pca_new = pca_new.fit_transform(x_train_new)
X_test_pca_new = pca_new.transform(x_test_new)
X_pca_new = pca_new.fit_transform(x_new)

model_new = LinearRegression()
model_new.fit(X_train_pca_new, y_train_new)
y_pred_new = model_new.predict(X_test_pca_new)

mse = mean_squared_error(y_test_new, y_pred_new)
r2 = r2_score(y_test_new, y_pred_new)
rmse = np.sqrt(mse)
cv_scores = cross_val_score(model_new, X_pca_new, y_new, cv=5,scoring='r2')

print(f'(MSE): {mse}')
print(f'(RMSE): {rmse}')
print(f'(R²): {r2}')
print(f'(cv_score): {cv_scores.mean()}')
# Out:
# (MSE): 184554.64147200328
# (RMSE): 429.59823262206663
# (R²): 0.8692265401936591
# (cv_score): 0.7855041493296226

# %%
x_new_ori = df_mAvgFourNew_v2.iloc[:,14:] #only economic variables
y_new = df_mAvgFourNew_v2.iloc[:,0]
x_train_new,x_test_new,y_train_new,y_test_new = train_test_split(x_new_ori,y_new,test_size=0.3,random_state=1,shuffle=True)
sc = StandardScaler()
x_train_new = sc.fit_transform(x_train_new)
x_test_new = sc.transform(x_test_new)
x_new_ori
# Out:
#      V-2_V-11.mA4l  V-2_V-12.mA4l  V-2_V-13.mA4l  V-2_V-14.mA4l  \
# 0     1.906931e+07     171911.250     188488.125      16427.250
# 1     2.388300e+07     760000.000     760000.000      22059.000
# 2     9.850800e+06     190320.000     194076.000       6396.000
# 3     1.797086e+06       7826.125       5298.475       1380.275
# 4     1.958550e+07     548775.000     454485.000      17542.500
# ..             ...            ...            ...            ...
# 367   4.419900e+06     128317.500     128310.750       3952.125
# 368   3.780000e+06      33750.000      37096.500       3166.500
# 369   5.316675e+06     215602.500     199153.250       4944.750
# 370   1.457580e+06      36388.500      39267.450       1243.125
# 371   4.724565e+06      44299.750      51379.700       3824.775
#
#      V-2_V-15.mA4l  V-2_V-16.mA4l  V-2_V-17.mA4l  V-2_V-18.mA4l  \
# 0     9.146089e+08   1.089624e+07    187661.2500     471523.500
# 1     4.685164e+09   2.969453e+07    760000.0000     991800.000
# 2     7.067453e+08   5.811120e+06    162840.0000     857400.000
# 3     2.343714e+07   2.301429e+05      8355.2875      24725.075
# 4     4.466781e+09   3.013230e+07    602025.0000     737445.000
# ..             ...            ...            ...            ...
# 367   7.785365e+08   5.026455e+06    131152.5000     218700.000
# 368   1.856918e+08   2.217525e+06     38145.0000      94782.000
# 369   1.428494e+09   9.567878e+06    205057.5000     312502.500
# 370   2.155441e+08   2.410566e+06     42419.2500     115017.750
# 371   1.969447e+08   2.088140e+06     43521.0000     120706.250
#
#      V-2_V-19.mA4l  V-2_V-20.mA4l  ...  V-3_V-20.mA4l  V-3_V-21.mA4l  \
# 0     2.452393e+07       756000.0  ...       220800.0   7.122870e+05
# 1     8.352544e+07      2622000.0  ...       393300.0   1.546268e+06
# 2     1.946731e+07      1080000.0  ...       189000.0   4.864458e+05
# 3     2.616358e+05        32880.0  ...         9696.0   3.519706e+04
# 4     1.302090e+08       429000.0  ...       114400.0   2.013920e+06
# ..             ...            ...  ...            ...            ...
# 367   1.379196e+07       182250.0  ...        47250.0   4.515787e+05
# 368   4.794682e+06        53100.0  ...        13275.0   1.193212e+05
# 369   3.930839e+07       199500.0  ...        45150.0   7.027597e+05
# 370   4.899423e+06        66555.0  ...        20880.0   1.583800e+05
# 371   5.810365e+06        80100.0  ...        20700.0   1.662900e+05
#
#      V-3_V-22.mA4l  V-3_V-23.mA4l  V-3_V-24.mA4l  V-3_V-25.mA4l  \
# 0       760288.000     1614600.00      7368050.0       59634.40
# 1      1634589.000     9939135.60      9970155.0      113997.15
# 2       552921.600     1474200.00      5434590.0       36147.30
# 3        39781.375      303342.39       312494.0        2149.28
# 4      2260380.000     7425876.00      7485800.0      116970.00
# ..             ...            ...            ...            ...
# 367     488092.500     3009716.50      3019800.0       33724.25
# 368     128568.750      494605.50      1200600.0       10052.25
# 369     754531.750     3851374.55      3859465.0       46999.00
# 370     183324.000     1295955.20      1303560.0       12959.60
# 371     177709.500      403650.00      1883297.5       13383.70
#
#      V-3_V-26.mA4l  V-3_V-27.mA4l  V-3_V-28.mA4l  V-3_V-29.mA4l
# 0        54919.400   3.227572e+06   2.448752e+07   5.599464e+08
# 1       114000.000   1.463323e+07   3.275078e+07   1.192702e+09
# 2        30013.200   1.302517e+06   2.050965e+07   3.789513e+08
# 3         1921.525   9.733067e+04   4.150178e+06   2.606407e+07
# 4       122700.000   7.844400e+06   2.478600e+07   1.528432e+09
# ..             ...            ...            ...            ...
# 367      33641.125   4.428466e+06   9.956100e+06   3.434332e+08
# 368       9299.250   5.602222e+05   4.003059e+06   9.288266e+07
# 369      47464.475   4.864646e+06   1.253558e+07   5.074131e+08
# 370      12540.800   1.034232e+06   4.404750e+06   1.252656e+08
# 371      11555.775   6.215629e+05   5.952256e+06   1.393028e+08
#
# [372 rows x 38 columns]

# %%
sc = StandardScaler()
x_new = sc.fit_transform(x_new_ori)

# %%
scores = []

n_components_new = range(1, x_train_new.shape[1] + 1)

for n_new in n_components_new:
    pca_new = PCA(n_components=n_new)
    X_pca_new = pca_new.fit_transform(x_new)

    model = LinearRegression()
    score = cross_val_score(model, X_pca_new, y_new, cv=5)
    scores.append(score.mean())
       

# Draw RMSE plot
plt.figure(figsize=(12, 6))
plt.plot(n_components_new, scores, marker='o')
plt.title('cvscore vs. Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('cvscore of new data')
plt.grid()

plt.show()


best_components_new = n_components_new[np.argmax(scores)]
print(f'Best value of n_components : {best_components_new}')
# Out:
# Best value of n_components : 1

# %%
pca_new = PCA(n_components=1)
X_train_pca_new = pca_new.fit_transform(x_train_new)
X_test_pca_new = pca_new.transform(x_test_new)
X_pca_new = pca_new.fit_transform(x_new)

model_new = LinearRegression()
model_new.fit(X_train_pca_new, y_train_new)
y_pred_new = model_new.predict(X_test_pca_new)

mse = mean_squared_error(y_test_new, y_pred_new)
r2 = r2_score(y_test_new, y_pred_new)
rmse = np.sqrt(mse)
cv_scores = cross_val_score(model_new, X_pca_new, y_new, cv=5,scoring='r2')

print(f'(MSE): {mse}')
print(f'(RMSE): {rmse}')
print(f'(R²): {r2}')
print(f'(cv_score): {cv_scores.mean()}')
# Out:
# (MSE): 1134141.9693701756
# (RMSE): 1064.9610177702166
# (R²): 0.1963590399940478
# (cv_score): -2.4978240516485815
